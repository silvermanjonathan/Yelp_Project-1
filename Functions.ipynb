# %%
#Import all packages for the Yelp Project
#Create connection to connection to created database

import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
conn = sqlite3.connect('yelp.db')
#:memory:
cur = conn.cursor()

# %%
#Create two variables for the business and review databases from yelp

url = 'https://api.yelp.com/v3/businesses/search'
url2 = 'https://api.yelp.com/v3/businesses/{id}/reviews'

# %%
#Connection to the Yelp API with the keys created 
client_id = "WdeBQ0QfW7ctlNNGDyNEwA"
api_key = "qOP1w_dBiefuyHCkz5gzIlhtKzNxBNMi3uCVJib_Kzs_y0EKqn1pKpRlpGvAPmB2fZ_eVWv65j_o5rmiT9HNK10tH5rosM3GfauVdQU0TvfOtdqn4L3zzLC2g1P3X3Yx"

# %%
#
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %%
term = 'yoga'
location = 'Manhattan'
radius = 10000

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "radius" : radius,
                "limit": 50
            }

# %%
def yelp_call(url, url_params, api_key):
    # your code to make the yelp call
    response = requests.get(url, headers=headers, params=url_params)
    data = response.json()
    return data

# %%
NYCdata = yelp_call(url, url_params, api_key)

# %%
NYCdata
# Out:
# {'businesses': [{'id': 'kmj7FnZsKPPH3psbR9tX7Q',
#    'alias': 'sonic-yoga-new-york',
#    'name': 'Sonic Yoga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/72XvEESqvzJCTA5E4o9XiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sonic-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 146,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7657608, 'longitude': -73.9831765},
#    'transactions': [],
#    'location': {'address1': '944 8th Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['944 8th Ave', 'Fl 2', 'New York, NY 10019']},
#    'phone': '+12123976344',
#    'display_phone': '(212) 397-6344',
#    'distance': 731.7016468023255},
#   {'id': 'GgvXfu8U80tcrxythjpB4w',
#    'alias': 'atthenayoga-new-york',
#    'name': 'AtthenaYoga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SBn4yaEVUCLUYxtMJhAcJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atthenayoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 42,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75686, 'longitude': -73.9807},
#    'transactions': [],
#    'location': {'address1': '43 W 46th St',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 W 46th St', 'Fl 4', 'New York, NY 10036']},
#    'phone': '+18568409436',
#    'display_phone': '(856) 840-9436',
#    'distance': 406.0168437486089},
#   {'id': 'TlDcvf1cEK2im6e4AFYe3A',
#    'alias': 'humming-puppy-new-york',
#    'name': 'Humming Puppy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7tBnyQDCRoAUJKXEDCzRcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/humming-puppy-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 90,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7434918, 'longitude': -73.9934249},
#    'transactions': [],
#    'location': {'address1': '119 W 23rd St',
#     'address2': 'Level 2 , Ste 200',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['119 W 23rd St',
#      'Level 2 , Ste 200',
#      'New York, NY 10011']},
#    'phone': '+12124140800',
#    'display_phone': '(212) 414-0800',
#    'distance': 2244.61472266589},
#   {'id': 'npgq_up0_puDV5jieUza-A',
#    'alias': 'yo-yoga-new-york',
#    'name': 'Yo Yoga!',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7JwxXGqeAj1SKD0gEkeKDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yo-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 55,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7595940180002,
#     'longitude': -73.9626122089538},
#    'transactions': [],
#    'location': {'address1': '344 E 59th St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['344 E 59th St', 'Fl 3', 'New York, NY 10022']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1339.9557243771724},
#   {'id': 'Oi85AYz9-Bx-9SBjNf__vg',
#    'alias': 'yoga-spa-lounge-1881-new-york',
#    'name': 'Yoga Spa Lounge 1881',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8_GzGAK20kfgWwO-68Sv3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoga-spa-lounge-1881-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 92,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'acupuncture', 'title': 'Acupuncture'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.757645, 'longitude': -73.9678601},
#    'transactions': [],
#    'location': {'address1': '226 E 54th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['226 E 54th St', 'New York, NY 10022']},
#    'phone': '+12123086789',
#    'display_phone': '(212) 308-6789',
#    'distance': 940.6433853845399},
#   {'id': 'nuhFcWqgHBwmgwlbm4rI9w',
#    'alias': 'yoga-union-new-york',
#    'name': 'Yoga Union',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8h4N0tMNW44iMxYbt1_ToQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoga-union-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 69,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74574, 'longitude': -73.9895},
#    'transactions': [],
#    'location': {'address1': '37 W 28th St',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37 W 28th St', 'Fl 4', 'New York, NY 10001']},
#    'phone': '+12125107404',
#    'display_phone': '(212) 510-7404',
#    'distance': 1855.6558217067304},
#   {'id': 'Chuu09nqfEQbREmaphoOuw',
#    'alias': 'mangoh-yoga-new-york',
#    'name': "Mang'Oh Yoga",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/McXvTykQZp4xts7i60odAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mangoh-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 85,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747277, 'longitude': -73.972662},
#    'transactions': [],
#    'location': {'address1': '322 E 39th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['322 E 39th St', 'New York, NY 10016']},
#    'phone': '+12126616655',
#    'display_phone': '(212) 661-6655',
#    'distance': 1520.3617339296914},
#   {'id': 'FK_6tqTQuSkadiWQ1w8ttQ',
#    'alias': 'three-jewels-new-york',
#    'name': 'Three Jewels',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TYrpYAtaQ7kDDkzecjWQZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-jewels-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 57,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7263467, 'longitude': -73.9911356},
#    'transactions': [],
#    'location': {'address1': '5 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 3rd St', 'New York, NY 10003']},
#    'phone': '+16469645736',
#    'display_phone': '(646) 964-5736',
#    'distance': 3913.5162264338383},
#   {'id': 'nkUwnPPYmCICZ8nYCu_twg',
#    'alias': 'yogamaya-new-york',
#    'name': 'Yogamaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uhvnSV8EEEE6aK9-JwtsfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yogamaya-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 138,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7418524, 'longitude': -73.9955771},
#    'transactions': [],
#    'location': {'address1': '135 W 20th St',
#     'address2': 'Fl 6',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 W 20th St', 'Fl 6', 'New York, NY 10011']},
#    'phone': '+12126754555',
#    'display_phone': '(212) 675-4555',
#    'distance': 2497.643507996589},
#   {'id': 'XpY0Cxo_Iw2deqeY6zsNOA',
#    'alias': 'earth-yoga-nyc-new-york',
#    'name': 'Earth Yoga NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u-tnn4nGSsLL9bhPNwybDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earth-yoga-nyc-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 83,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7611883, 'longitude': -73.9620342},
#    'transactions': [],
#    'location': {'address1': '328 E 61st St',
#     'address2': 'Fl 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['328 E 61st St', 'Fl 1', 'New York, NY 10065']},
#    'phone': '+16467264710',
#    'display_phone': '(646) 726-4710',
#    'distance': 1391.0591609016155},
#   {'id': 'tGtrhu0YDGkM9ECrYVz6xg',
#    'alias': 'modo-yoga-nyc-west-village-new-york-2',
#    'name': 'Modo Yoga NYC - West Village',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TwujVSlNlX6Ox7ZZ3hv4Kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/modo-yoga-nyc-west-village-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 167,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7345617375926,
#     'longitude': -73.9987192654828},
#    'transactions': [],
#    'location': {'address1': '434 6th Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['434 6th Ave', 'Fl 2', 'New York, NY 10011']},
#    'phone': '+12127809642',
#    'display_phone': '(212) 780-9642',
#    'distance': 3322.3216939488775},
#   {'id': 'omwcHHgdgUJn-W1b3i78og',
#    'alias': 'upper-west-side-yoga-and-wellness-new-york',
#    'name': 'Upper West Side Yoga and Wellness',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WB2qBHjl83tDc-gM_Wu7DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upper-west-side-yoga-and-wellness-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 58,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78573, 'longitude': -73.97224},
#    'transactions': [],
#    'location': {'address1': '75B W 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75B W 85th St', 'New York, NY 10024']},
#    'phone': '+12125952221',
#    'display_phone': '(212) 595-2221',
#    'distance': 2886.402262438881},
#   {'id': 'Mc17IR6PG4iZLmZzciJEQQ',
#    'alias': 'world-yoga-center-new-york',
#    'name': 'World Yoga Center',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jNnFA2_k-XWpMwbLDkSsRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/world-yoga-center-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 16,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7798614501953,
#     'longitude': -73.9838638305664},
#    'transactions': [],
#    'location': {'address1': '265 W 72nd St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 W 72nd St', 'Fl 2', 'New York, NY 10023']},
#    'phone': '+12127874908',
#    'display_phone': '(212) 787-4908',
#    'distance': 2227.1763594758945},
#   {'id': 'oECxp7RoWT2QArWgqpwnMA',
#    'alias': 'sky-ting-yoga-chinatown-new-york-2',
#    'name': 'SKY TING YOGA - Chinatown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FmW7HuKEuPV03r68uE-OVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sky-ting-yoga-chinatown-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 53,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71533, 'longitude': -73.99264},
#    'transactions': [],
#    'location': {'address1': '17 Allen',
#     'address2': 'Fl 7',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Allen', 'Fl 7', 'New York, NY 10002']},
#    'phone': '+12122035786',
#    'display_phone': '(212) 203-5786',
#    'distance': 5135.216867785002},
#   {'id': 'x0bjd5AUu3ASzfjmht2IYA',
#    'alias': 'reflections-center-for-conscious-living-and-yoga-new-york-5',
#    'name': 'Reflections, Center for Conscious Living & Yoga',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6k2h7eiBuklxMMh-Hl1mdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/reflections-center-for-conscious-living-and-yoga-new-york-5?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 50,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7391382, 'longitude': -73.9814689},
#    'transactions': [],
#    'location': {'address1': '227 E 24th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 E 24th St', 'New York, NY 10010']},
#    'phone': '+12129742288',
#    'display_phone': '(212) 974-2288',
#    'distance': 2353.008307012446},
#   {'id': 'c_80f3N3NbWDX8RnvuM3Xg',
#    'alias': 'yoga-la-vie-new-york-2',
#    'name': 'Yoga La Vie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AOhd3o_UM0lscElVjv0G7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoga-la-vie-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 29,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7701819, 'longitude': -73.9590077},
#    'transactions': [],
#    'location': {'address1': '215 E 73rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 E 73rd St', 'New York, NY 10021']},
#    'phone': '+19293903300',
#    'display_phone': '(929) 390-3300',
#    'distance': 1980.7172868211715},
#   {'id': '89VGtFw9HZASM0IdnSEeFA',
#    'alias': 'house-of-jai-yoga-new-york',
#    'name': 'House of Jai Yoga',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zNDu2UXK2oh75pUdiLwYrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-jai-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 23,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76997, 'longitude': -73.95366},
#    'transactions': [],
#    'location': {'address1': '1456 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1456 1st Ave', 'New York, NY 10021']},
#    'phone': '+16468613659',
#    'display_phone': '(646) 861-3659',
#    'distance': 2338.5273653960553},
#   {'id': 'KjSI9xkCFTrRRbHOzCG7xg',
#    'alias': 'inhale-nyc-new-york',
#    'name': 'Inhale NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7q4N59DpThOiu_aun6anIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/inhale-nyc-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 1,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75248, 'longitude': -73.97342},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10017']},
#    'phone': '+13057673737',
#    'display_phone': '(305) 767-3737',
#    'distance': 1173.5002106356526},
#   {'id': 'PZhmOvUx0HrdGvxVrxTJ5g',
#    'alias': 'ny-loves-yoga-new-york-3',
#    'name': 'NY Loves Yoga',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bQSgsyMHUBTR8wnotCwLQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-loves-yoga-new-york-3?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 56,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7849960327148,
#     'longitude': -73.9752731323242},
#    'transactions': [],
#    'location': {'address1': '140 W 83rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W 83rd St', 'New York, NY 10024']},
#    'phone': '+12128779642',
#    'display_phone': '(212) 877-9642',
#    'distance': 2768.4790448394297},
#   {'id': 'b1ziC3xpS5Bb9PGsufBYAw',
#    'alias': 'three-sisters-yoga-new-york',
#    'name': 'Three Sisters Yoga',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tAkzlrpNBySicatQFWVz3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/three-sisters-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 4,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.754502, 'longitude': -73.992165},
#    'transactions': [],
#    'location': {'address1': '545 Eighth Ave',
#     'address2': 'Ste 1540',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 Eighth Ave', 'Ste 1540', 'New York, NY 10018']},
#    'phone': '+13148964203',
#    'display_phone': '(314) 896-4203',
#    'distance': 1314.6141251435363},
#   {'id': 'NqL3lVZgh1pz0tVaZBxkRg',
#    'alias': 'sacred-greenwich-village-new-york',
#    'name': 'Sacred - Greenwich Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c-i12pCcABAg4sBe1-89IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sacred-greenwich-village-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 133,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'aerialfitness', 'title': 'Aerial Fitness'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72881, 'longitude': -73.99994},
#    'transactions': [],
#    'location': {'address1': '163 Bleecker St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['163 Bleecker St', 'Fl 2', 'New York, NY 10012']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3937.078350163732},
#   {'id': 'vxNBDgBMP44E8DHuqj5z6A',
#    'alias': 'standard-dose-new-york-2',
#    'name': 'Standard Dose',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kWoCoHGlBIYw9UcbAcxsvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/standard-dose-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 6,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7441, 'longitude': -73.9891},
#    'transactions': [],
#    'location': {'address1': '1145 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1145 Broadway', 'New York, NY 10001']},
#    'phone': '+12125479453',
#    'display_phone': '(212) 547-9453',
#    'distance': 2006.071287135312},
#   {'id': 'dzvqCMHOsvruyOZZ8wSnbA',
#    'alias': 'naked-in-motion-new-york',
#    'name': 'Naked in Motion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wlZXj9C3x_3-6qNgD11w5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naked-in-motion-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 2,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'pilates', 'title': 'Pilates'},
#     {'alias': 'nudist', 'title': 'Nudist'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74868, 'longitude': -73.99462},
#    'transactions': [],
#    'location': {'address1': '245 West 29th St',
#     'address2': 'Fl 11',
#     'address3': 'Wild Studio',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['245 West 29th St',
#      'Fl 11',
#      'Wild Studio',
#      'New York, NY 10001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1851.370926775851},
#   {'id': 'I3-EsRgXDcLx3OrlACCx3Q',
#    'alias': 'hot-on-yoga-27th-new-york-2',
#    'name': 'Hot On Yoga 27th',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qqddpu4hRsSiLWNfUduwaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-on-yoga-27th-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 180,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745951, 'longitude': -73.991752},
#    'transactions': [],
#    'location': {'address1': '115 W 27th St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 W 27th St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+19175739642',
#    'display_phone': '(917) 573-9642',
#    'distance': 1939.483455445304},
#   {'id': 'qFJcpI5TOBQkX6BukZqUVw',
#    'alias': 'exhale-nomad-new-york',
#    'name': 'Exhale Nomad',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i9lyvzKyrXHJKav-ifBNHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exhale-nomad-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 4,
#    'categories': [{'alias': 'barreclasses', 'title': 'Barre Classes'},
#     {'alias': 'spas', 'title': 'Day Spas'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.746417, 'longitude': -73.983196},
#    'transactions': [],
#    'location': {'address1': '31 East 32nd St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['31 East 32nd St', 'New York, NY 10016']},
#    'phone': '+12125616470',
#    'display_phone': '(212) 561-6470',
#    'distance': 1583.6328777537728},
#   {'id': '6-fZD_ZzKJo29zapElbOZg',
#    'alias': 'yoga-216-new-york',
#    'name': 'Yoga 216',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-wTbcwsp7U7FGR42LXFV_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoga-216-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 18,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.746285, 'longitude': -74.006063},
#    'transactions': [],
#    'location': {'address1': '511 W 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['511 W 20th St', 'New York, NY 10011']},
#    'phone': '+12123373530',
#    'display_phone': '(212) 337-3530',
#    'distance': 2790.9552095037084},
#   {'id': 'HcsOCtxnSpAmUU0EC_AGMQ',
#    'alias': 'woom-center-new-york',
#    'name': 'WOOM CENTER',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KB_yNTLoWH5ecJzV0DlilQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/woom-center-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 52,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7233835774943, 'longitude': -73.9931225},
#    'transactions': [],
#    'location': {'address1': '274 Bowery',
#     'address2': 'Fl 2',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Bowery', 'Fl 2', 'New York, NY 10012']},
#    'phone': '+16466785092',
#    'display_phone': '(646) 678-5092',
#    'distance': 4276.7118572270065},
#   {'id': 'JvwVi-ZOfGKQEiezZTCgEA',
#    'alias': 'stanton-street-yoga-new-york-2',
#    'name': 'Stanton Street Yoga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6Aby7yu6GvfCYNTeYjaSsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stanton-street-yoga-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 83,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720008, 'longitude': -73.983032},
#    'transactions': [],
#    'location': {'address1': '196A Stanton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['196A Stanton St', 'New York, NY 10002']},
#    'phone': '+17873962092',
#    'display_phone': '(787) 396-2092',
#    'distance': 4491.568388599109},
#   {'id': 'PISWOLCiOj47QbZKm-F3tg',
#    'alias': 'five-pillars-yoga-new-york',
#    'name': 'Five Pillars Yoga',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2fh7FH_2fsyeXTZR-ZCVxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-pillars-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 38,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'},
#     {'alias': 'pilates', 'title': 'Pilates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78491, 'longitude': -73.95616},
#    'transactions': [],
#    'location': {'address1': '1298 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1298 Madison Ave', 'New York, NY 10128']},
#    'phone': '+12124266111',
#    'display_phone': '(212) 426-6111',
#    'distance': 3330.206641759609},
#   {'id': 'cwADiq0xORmv4QA2jhu-Pw',
#    'alias': 'rachel-bennett-yoga-new-york',
#    'name': 'Rachel Bennett Yoga',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BB_XQ1uHNrIH0wdYg-b-Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rachel-bennett-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 2,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7781173, 'longitude': -73.979766},
#    'transactions': [],
#    'location': {'address1': '131 W 72nd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['131 W 72nd St', 'New York, NY 10023']},
#    'phone': '+19175381949',
#    'display_phone': '(917) 538-1949',
#    'distance': 1993.5039144489417},
#   {'id': 'fiLGdKwhkvK6pZ3E_GjHmQ',
#    'alias': 'lyons-den-power-yoga-new-york-4',
#    'name': 'Lyons Den Power Yoga',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JJLZW-P1ueRp_hQ7X7g9cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lyons-den-power-yoga-new-york-4?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 14,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74162, 'longitude': -74.00075},
#    'transactions': [],
#    'location': {'address1': '267 W 17th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['267 W 17th St', 'Fl 2', 'New York, NY 10011']},
#    'phone': '+16469644583',
#    'display_phone': '(646) 964-4583',
#    'distance': 2789.7812444245096},
#   {'id': 'qhjcMZivcYfr7CaTHkiXXg',
#    'alias': 'surf-yoga-beer-new-york',
#    'name': 'Surf Yoga Beer',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tpos_oYgjUEPfGhwCKeEWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surf-yoga-beer-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 31,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'surfing', 'title': 'Surfing'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.745916, 'longitude': -73.983916},
#    'transactions': [],
#    'location': {'address1': '135 Madison Ave',
#     'address2': 'Fl 5',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['135 Madison Ave', 'Fl 5', 'New York, NY 10016']},
#    'phone': '+12135903279',
#    'display_phone': '(213) 590-3279',
#    'distance': 1654.1115597481344},
#   {'id': 'P5OZCF6xChJtWNrjNFBBRA',
#    'alias': 'new-york-yoga-new-york-4',
#    'name': 'New York Yoga',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uYiSgsUofXbfvDGfNestdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-yoga-new-york-4?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 93,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7758165, 'longitude': -73.9473755},
#    'transactions': [],
#    'location': {'address1': '1629 York Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1629 York Ave', 'New York, NY 10028']},
#    'phone': '+12127179642',
#    'display_phone': '(212) 717-9642',
#    'distance': 3138.265732106075},
#   {'id': 'gbRr9zRxpBtBLum9kMlxZw',
#    'alias': 'ashtanga-yoga-upper-west-side-manhattan',
#    'name': 'Ashtanga Yoga Upper West Side',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V6GxnxxJ7vsgCp5xFz9Azg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ashtanga-yoga-upper-west-side-manhattan?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 8,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77946, 'longitude': -73.98291},
#    'transactions': [],
#    'location': {'address1': '239 W 72nd St',
#     'address2': 'Ste 4, Fl 2',
#     'address3': '',
#     'city': 'Manhattan',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 W 72nd St',
#      'Ste 4, Fl 2',
#      'Manhattan, NY 10023']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2167.451930009611},
#   {'id': 'hW_eQNgyPkfwAH4Gq6I6LQ',
#    'alias': 'now-yoga-new-york',
#    'name': 'Now Yoga',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HMp-vYNHiDBAhVrZPNsiCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/now-yoga-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 6,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73075, 'longitude': -73.99016},
#    'transactions': [],
#    'location': {'address1': '61 4th Ave',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['61 4th Ave', 'Fl 3', 'New York, NY 10003']},
#    'phone': '+16465967772',
#    'display_phone': '(646) 596-7772',
#    'distance': 3421.012506603611},
#   {'id': 'Vi_qAjnkRk4kCaMpx_-Gkg',
#    'alias': 'illumina-east-new-york',
#    'name': 'Illumina East',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JCusljzMVfLAEszBHrlAfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/illumina-east-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 7,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72469, 'longitude': -73.98164},
#    'transactions': [],
#    'location': {'address1': '96 Ave B',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Ave B', 'New York, NY 10009']},
#    'phone': '+16468510355',
#    'display_phone': '(646) 851-0355',
#    'distance': 3956.3098893636143},
#   {'id': 'Vwy58_3fyh1LwcMCFGb5vQ',
#    'alias': 'brick-new-york-new-york-5',
#    'name': 'BRICK New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UBY423GkWFP3LnPcC5oS6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brick-new-york-new-york-5?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 20,
#    'categories': [{'alias': 'sports_clubs', 'title': 'Sports Clubs'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535734661792,
#     'longitude': -73.9742496362698},
#    'transactions': [],
#    'location': {'address1': '465 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['465 Lexington Ave', 'New York, NY 10017']},
#    'phone': '+19173882666',
#    'display_phone': '(917) 388-2666',
#    'distance': 820.7076774740353},
#   {'id': 'Z1WcVd9DXCzU5az3PueunQ',
#    'alias': 'new-love-city-brooklyn',
#    'name': 'New Love City',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9OL8JUw0X4ZuPibrXrn3GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-love-city-brooklyn?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 42,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7296982, 'longitude': -73.9582672},
#    'transactions': [],
#    'location': {'address1': '68 Greenpoint Ave',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['68 Greenpoint Ave', 'Fl 4', 'Brooklyn, NY 11222']},
#    'phone': '+16169154576',
#    'display_phone': '(616) 915-4576',
#    'distance': 3796.2902822570286},
#   {'id': 'Ai7Go_R0snWuiCL6rbYIXQ',
#    'alias': 'body-evolution-west-72nd-new-york-2',
#    'name': 'Body Evolution West 72nd',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uYUTZazeh32BEGuBTQ-khg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/body-evolution-west-72nd-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 5,
#    'categories': [{'alias': 'pilates', 'title': 'Pilates'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77789, 'longitude': -73.98035},
#    'transactions': [],
#    'location': {'address1': '140 W 72nd St',
#     'address2': 'Fl 2 Buzzer 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W 72nd St',
#      'Fl 2 Buzzer 1',
#      'New York, NY 10023']},
#    'phone': '+12125107212',
#    'display_phone': '(212) 510-7212',
#    'distance': 1963.1595571517416},
#   {'id': 't2nv84yKVqk0PwsNTjBcUQ',
#    'alias': 'yoga-agora-astoria',
#    'name': 'Yoga Agora',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KSzcKdrNlHiiPx_8Qmmdhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoga-agora-astoria?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 229,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76093, 'longitude': -73.92381},
#    'transactions': [],
#    'location': {'address1': '33-02 Broadway',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-02 Broadway', 'Fl 2', 'Astoria, NY 11106']},
#    'phone': '+17186260680',
#    'display_phone': '(718) 626-0680',
#    'distance': 4609.725723244701},
#   {'id': 'NT2cSYhGgiJ-RgjtuNj3fQ',
#    'alias': 'sivananda-yoga-vedanta-center-new-york',
#    'name': 'Sivananda Yoga Vedanta Center',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J6B90YtGdxljUcBubAt7bQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sivananda-yoga-vedanta-center-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 39,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.745712, 'longitude': -73.996856},
#    'transactions': [],
#    'location': {'address1': '243 W 24th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['243 W 24th St', 'New York, NY 10011']},
#    'phone': '+12122554560',
#    'display_phone': '(212) 255-4560',
#    'distance': 2237.732949936123},
#   {'id': 'Bl8Z1G6mT8e6v5Ghr8P0Ng',
#    'alias': 'harlem-yoga-studio-new-york',
#    'name': 'Harlem Yoga Studio',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kJjwvS0Go46evrOK4hh_DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-yoga-studio-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 59,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.806855, 'longitude': -73.944059},
#    'transactions': [],
#    'location': {'address1': '44 W 125th St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44 W 125th St', 'Fl 3', 'New York, NY 10027']},
#    'phone': '+19175380457',
#    'display_phone': '(917) 538-0457',
#    'distance': 5941.779669075716},
#   {'id': '8SDiypaoRC4TvrRz6wWRmg',
#    'alias': 'warrior-bridge-new-york',
#    'name': 'Warrior Bridge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FUPB2XFCD2zaKOrNvMK-MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/warrior-bridge-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 16,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'physicaltherapy', 'title': 'Physical Therapy'},
#     {'alias': 'pilates', 'title': 'Pilates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7083959, 'longitude': -74.001063},
#    'transactions': [],
#    'location': {'address1': '250 Front St',
#     'address2': '',
#     'address3': 'Ground Fl',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 Front St', 'Ground Fl', 'New York, NY 10038']},
#    'phone': '+19172620863',
#    'display_phone': '(917) 262-0863',
#    'distance': 6067.515179956639},
#   {'id': 'TQpMRElRg2cTKZI50W8Veg',
#    'alias': 'integral-yoga-institute-new-york',
#    'name': 'Integral Yoga Institute',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WpaqJQHeRf7QrB9yMQh-BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/integral-yoga-institute-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 89,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'reiki', 'title': 'Reiki'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73852, 'longitude': -74.00145},
#    'transactions': [],
#    'location': {'address1': '227 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 W 13th St', 'New York, NY 10011']},
#    'phone': '+12129290585',
#    'display_phone': '(212) 929-0585',
#    'distance': 3090.3879128389963},
#   {'id': 'LvBTSQy3Zdx01WTKIr4Xrg',
#    'alias': 'ra-ma-yoga-institute-new-york',
#    'name': 'RA MA Yoga Institute',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u58ueG1-jF4FXKkwv_wwMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ra-ma-yoga-institute-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 7,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'meditationcenters', 'title': 'Meditation Centers'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72075, 'longitude': -73.98679},
#    'transactions': [],
#    'location': {'address1': '125 Stanton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 Stanton St', 'New York, NY 10002']},
#    'phone': '+19172616228',
#    'display_phone': '(917) 261-6228',
#    'distance': 4441.728634801856},
#   {'id': '0QMXNHybK3sgpB-B5RvvdA',
#    'alias': 'yoga-vida-noho-new-york-8',
#    'name': 'Yoga Vida - NoHo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zG7SSGT2KAHVzLrdfboXcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yoga-vida-noho-new-york-8?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 125,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7268684989549,
#     'longitude': -73.9952158927917},
#    'transactions': [],
#    'location': {'address1': '666 Broadway',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['666 Broadway', 'Fl 3', 'New York, NY 10012']},
#    'phone': '+12128459973',
#    'display_phone': '(212) 845-9973',
#    'distance': 3966.348961630725},
#   {'id': 'tH2owtqitA7hv1A2Ay0ZhQ',
#    'alias': 'the-fit-co-new-york',
#    'name': 'The Fit Co',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DTaapOTZrnth8V8w5uMgow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fit-co-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 11,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'pilates', 'title': 'Pilates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7633285522461,
#     'longitude': -73.9763336181641},
#    'transactions': [],
#    'location': {'address1': '39 W 56th St',
#     'address2': 'Fl 4',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 56th St', 'Fl 4', 'New York, NY 10019']},
#    'phone': '+19176858032',
#    'display_phone': '(917) 685-8032',
#    'distance': 395.20748188332175},
#   {'id': '_Uu-HDdYlY9Eh5OqMYZezQ',
#    'alias': 'lyons-den-power-yoga-tribeca-new-york',
#    'name': 'Lyons Den Power Yoga - TriBeCa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8T9hoQuzIkH_MpSrAdCXuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lyons-den-power-yoga-tribeca-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 52,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7186473680678,
#     'longitude': -74.0050053618713},
#    'transactions': [],
#    'location': {'address1': '279 Church St',
#     'address2': 'Fl 2',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['279 Church St', 'Fl 2', 'New York, NY 10013']},
#    'phone': '+16464908888',
#    'display_phone': '(646) 490-8888',
#    'distance': 5133.257549464567},
#   {'id': 'ZvETO2Xbo_OKC3C2UiINyw',
#    'alias': 'ashtanga-yoga-shala-new-york',
#    'name': 'Ashtanga Yoga Shala',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/54-fq26bxshY915EXcogtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ashtanga-yoga-shala-new-york?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 9,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723636, 'longitude': -73.9802448},
#    'transactions': [],
#    'location': {'address1': '638 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['638 E 6th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4070.0390073387193},
#   {'id': 'Zhw2qXOa9EJ5l0g6_QjDww',
#    'alias': 'dharma-yoga-center-new-york-2',
#    'name': 'Dharma Yoga Center',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7_Tf6T9Q14JH28frwtKsFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dharma-yoga-center-new-york-2?adjust_creative=WdeBQ0QfW7ctlNNGDyNEwA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=WdeBQ0QfW7ctlNNGDyNEwA',
#    'review_count': 90,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432016410603,
#     'longitude': -73.9918091779346},
#    'transactions': [],
#    'location': {'address1': '46 W 24th St',
#     'address2': 'Ground Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 W 24th St', 'Ground Floor', 'New York, NY 10010']},
#    'phone': '+12128898160',
#    'display_phone': '(212) 889-8160',
#    'distance': 2199.0123606347042}],
#  'total': 1200,
#  'region': {'center': {'longitude': -73.97850036621094,
#    'latitude': 40.76021491079617}}}

# %%
cur.execute("""CREATE TABLE businesses (
                                id INTEGER PRIMARY KEY, 
                                businessID TEXT,
                                rating INTEGER,
                                price TEXT,
                                name TEXT,
                                review_count TEXT,
                                city TEXT,
                                country TEXT,
                                zip_code TEXT
                                )          
            """)
conn.commit()

# %%
cur.execute("""CREATE TABLE reviews (
                                businessID TEXT,
                                text TEXT,
                                rating INTEGER,
                                time_created TEXT,
                                reviewID TEXT
                                )          
            """)
conn.commit()

# %%
def parse_results(results):
    biz_list = []

    for business in results['businesses']:
        for item in ['businessID', 'rating', 'price', 'name', 'review_count', 'city', 'country', 'zip_code']:
            if item not in business:
                business[item] = np.nan
            else: 
                business[item]
        biz_tuple = ( business['id'], 
                      business['rating'],
                      business['price'],
                      business['name'],
                      business['review_count'],
                      business['location']['city'],
                      business['location']['country'],
                      business['location']['zip_code']
                      )    
        biz_list.append(biz_tuple)
    return biz_list

# %%
def insert_values(conn, cur, parse_results):
        add_business = ("""
    INSERT INTO businesses (businessID, rating, price, name, review_count, city, country, zip_code)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?) """)
        cur.executemany(add_business, parse_results)
        conn.commit()

# %%
# create a variable  to keep track of which result you are in. 
current_offset = 0
#num = NYCdata['total']
#set up a while loop to go through and grab the result 
while current_offset < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = current_offset
    #make your API call with the new offset number
    results = yelp_call(url, url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    insert_values(conn, cur, parsed_results)
    #increment the counter by 50 to move on to the next results
    current_offset += 50
    print(current_offset)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000

# %%
location = 'London'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "radius" : radius,
                "limit": 50
            }

# %%
# create a variable  to keep track of which result you are in. 
current_offset = 0
#num = NYCdata['total']
#set up a while loop to go through and grab the result 
while current_offset < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = current_offset
    #make your API call with the new offset number
    results = yelp_call(url, url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    insert_values(conn, cur, parsed_results)
    #increment the counter by 50 to move on to the next results
    print(current_offset)
    current_offset += 50
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950

# %%
biz_list = cur.execute("""
SELECT businessID
FROM businesses;
""").fetchall()

# %%
biz_list
# Out:
# [('kmj7FnZsKPPH3psbR9tX7Q',),
#  ('GgvXfu8U80tcrxythjpB4w',),
#  ('TlDcvf1cEK2im6e4AFYe3A',),
#  ('npgq_up0_puDV5jieUza-A',),
#  ('Oi85AYz9-Bx-9SBjNf__vg',),
#  ('nuhFcWqgHBwmgwlbm4rI9w',),
#  ('Chuu09nqfEQbREmaphoOuw',),
#  ('FK_6tqTQuSkadiWQ1w8ttQ',),
#  ('nkUwnPPYmCICZ8nYCu_twg',),
#  ('XpY0Cxo_Iw2deqeY6zsNOA',),
#  ('tGtrhu0YDGkM9ECrYVz6xg',),
#  ('omwcHHgdgUJn-W1b3i78og',),
#  ('YgKiSTpw2badaYgxShBjkQ',),
#  ('ZRzkpcG7W84b0ukYwJQCng',),
#  ('u4TzZEjmzrqZpFcea5LD2w',),
#  ('SF_x8MNc3SI7PO6SaKmbuQ',),
#  ('lx4saYsRPK9kiCskpUAaww',),
#  ('EC_j2Oub12S5R34suUQGkw',),
#  ('vXBr2EPJa4TBkXCzY8aJCA',),
#  ('FCvutB7sglxMulXqoVASSQ',),
#  ('L-FvLWawzPb0YY4Zc4NsSg',),
#  ('cgbgv8DRHtOQ6-99UWRWUA',),
#  ('UtYrO3Yuf0aOxuI8x_nLmg',),
#  ('9fmI9NE0hsOnKeUfUETYlQ',),
#  ('m4shaTSFeHEYTZ5sLad5qQ',),
#  ('ZKpyVsGCqVWDVr2nl_agEg',),
#  ('Lw4UVdRnof8wLwg02dP6Qg',),
#  ('XdNdzhii1sCW2jh6PIf5Kw',),
#  ('2rGQmYEAp3777OdONqAeVg',),
#  ('eOqXigYmWoIRxwnCfLFDyA',),
#  ('QARBImstVuDE9c2lQDCJwg',),
#  ('9vdtU6X6Bl866PHioNT2PQ',),
#  ('ER3saHOKFplcgD79DA49EA',),
#  ('8QsqsSxnMyMjzFkWymtQ0w',),
#  ('bQf3u6mS2G2fXKM-3ev7XQ',),
#  ('3GuipCTZ2BmBAazKPEKebQ',),
#  ('0xXYCKOaZ6joxZtBBgi1Uw',),
#  ('R5sTa-S5GBwxTJF6xx7XkQ',),
#  ('wG96y8b8JISNmdATA_pnBQ',),
#  ('IU2Rc0EAfEp27F62RrVgyg',),
#  ('ikuE6l0lWOz2N6Flv2ZCYg',),
#  ('sytPIeQiGItDv58N8Iu8Xg',),
#  ('q37HTbcdfogO73dlRFYftA',),
#  ('KPlz9cT-4WWfxDN4d7bHTw',),
#  ('6LR6FxZOcqzK-5Oe41Yqag',),
#  ('UWJrhAPBk3tcqJa-XszGRQ',),
#  ('W7XmLlHOvF2MpE252lnL9A',),
#  ('vVE6pQFArPDeps2FhhkVxQ',),
#  ('ryhxaXvnYvDJiNYQqLKFTQ',),
#  ('PFcPwHy_sa13V7Kio5XpSA',),
#  ('xZNpQn19vydiLvKtDd-FOA',),
#  ('mrz-vVtNkx4b2PR6UbHg0w',),
#  ('i4Vd85r8Py6U2iVlDPaYmQ',),
#  ('-5h5zs6EHDEPP7xY4C_WDg',),
#  ('ZhainggV-I4ziYfoHEUqJA',),
#  ('aAisMje9Gxre1TLvxkOgAw',),
#  ('5HgQsbEhK2OKtQLhB9NNNw',),
#  ('leVqeIg0IAqHWij7oM3__w',),
#  ('f_Xot3Ev7E013MEnJxB18w',),
#  ('Mt1O4GaqTO1OTg3vkXCvDg',),
#  ('w2NWa1j5SOyFRL4AuABRbg',),
#  ('DfKCR99SUGHbGUFZxpt09g',),
#  ('Xx1oRsCre6AUyx_Y3n4Hbw',),
#  ('KZ6KXbwEHUdmHNgiMK-8-g',),
#  ('fbMRu1FN-th2cGZi5zTLAw',),
#  ('YQXqClu-AlnAnGsmpxBhsg',),
#  ('nPsgGBflzwsDNXWZfaq8dg',),
#  ('k4usFxFTUbDzffs_I4EDLA',),
#  ('AzzBQM-7vy4Jxdtq00u1MQ',),
#  ('9JXG0nabYZKRAhuqmZ30BA',),
#  ('JPj05XLKn1l64sCWICe6TA',),
#  ('186de0m26t7DKwYMQux-0g',),
#  ('pwXR06vtq3OOk3S0Y0d1Tw',),
#  ('2PtG7ZfUZEIneJjL1J_asg',),
#  ('mvoMgDSlR2550ON8Zfd8ZQ',),
#  ('8z4a0zHkCUGBs9rzO_PUoQ',),
#  ('1F-J5VdETnENPRwekXlPQQ',),
#  ('Ejzedv3Z1iL3g5wgMWi3kw',),
#  ('i-3B_mYHgW8Meefy29cFwA',),
#  ('3LHV1JOn4XNtwdDDhT5z0Q',),
#  ('FfwZ35YFVumEJtxolnBAyQ',),
#  ('WgWznoU9GUcfWq_xV0swvA',),
#  ('3ulKuV3srv0ef6ZUZi0S2A',),
#  ('0tGlyFj255z-zpjUQF72KQ',),
#  ('J4a6L0aB4Bxf4ny9iWgATQ',),
#  ('Gb5B2woQVydAt9jLKkGnuQ',),
#  ('9eQWqmedaEVfdMlmE_Z5FQ',),
#  ('7aQYHRCYxTKAmawDGJ3YIw',),
#  ('K_v5t4VQHcZLl4cxXieDig',),
#  ('vPOd4qVpR2GHPgFWibSxTw',),
#  ('E0MIC8s4yVO1sqbo7p756w',),
#  ('J0ltGSBhUA74Bfa41N_l6A',),
#  ('1FaknROANzU18ZM9AkDh8Q',),
#  ('1ZkYQV9eUXN_Ly2G7b2geQ',),
#  ('UR1bX2YHQ30Uqd7lxKIpxA',),
#  ('g6U_cqItMcGV3bFoNXeHsA',),
#  ('VrCe1XQvfNFPfz4oUt6LDQ',),
#  ('nTY5XYMOYGGHaQL5bam7RA',),
#  ('RmWS1_hCPIe32ftSQ9YMkA',),
#  ('St6DcyvaxUCX7hmHKTJqTQ',),
#  ('5CzEbYs8Q9tz0HJoKfww2Q',),
#  ('32sftcXK2dl_Yby1hM5-PA',),
#  ('DzlmPGxCg3wRyGJiNoSFow',),
#  ('PhCuetu-kKemRw2gU6QmGg',),
#  ('sWDLtbXuEI3u2ujIXmLZBA',),
#  ('rFc5Zv2igHfb5Rck2-Do0w',),
#  ('i-wKgEc81T4-btaFoq9dSA',),
#  ('MDzALh67nH1-czACyB_CIg',),
#  ('Mxiki9ZQnVuME1s1K4sCWw',),
#  ('LibpXNT-8J1Fw6tXnlUUxQ',),
#  ('4eNrOBG7efnVJHBK1nxBdg',),
#  ('xChemndh4IiTimutQfyeQQ',),
#  ('xFgdPZMWoYuaTgBftX8LPA',),
#  ('v_Yph0ri3SjRcCa5dyjlww',),
#  ('LfFtWAUNwD3zT2zOOqYuKg',),
#  ('x_WgugK5_Y_mZ32Ox5ACqg',),
#  ('VTLwCn7_0dgLrpPBjjFPLg',),
#  ('azhV4OzVokTwewrMFw7ECA',),
#  ('l08XMp4SRfHpq4Wk8hf4vQ',),
#  ('wORtAyvsfiBJtfZDWMnXjA',),
#  ('r1HvIAjWI9bCrElyrxBuSQ',),
#  ('OO9SgjbLi3nyt63hRir0LQ',),
#  ('eKUzNl4MvxbxLU6LCOY33A',),
#  ('WM-m1vQCMSfu6iDysNaoAQ',),
#  ('D1P7yspJBjOcyNiDBchnHw',),
#  ('6IhiqwZ0BS7Qfom3qrhWiQ',),
#  ('XOAkJJ759BF1HkapiyGg-Q',),
#  ('JlFLkNrg8k7qoOdhb-AeTA',),
#  ('-iA0I_ZcwEZdz7W8PEmJvA',),
#  ('DypJfifuqqZW60D9Gt9Gvw',),
#  ('GQHhowxLKEt509fWGSxtSQ',),
#  ('WNawSG7NIJWaN1QUsYOdRg',),
#  ('RJLCRtW_c5fZfGcLAEo2PQ',),
#  ('JiH5rnOlw7DzysKd41WdSg',),
#  ('fdY7Cus2Lo2nQrUv_M7zCw',),
#  ('Ag-dQZ3rGqt8W6CnlNJNqw',),
#  ('n0ZDEXWuGkqXSmkH7D60Dg',),
#  ('khP-qZ96sasIj8yhGsj-5Q',),
#  ('cyaM9MzkPFnyaYJTSqwN3Q',),
#  ('qb6TMcDuK2Nu4Y_vm85ldw',),
#  ('--3kLXdVcWt_HuhyyWwHOw',),
#  ('bX9sN1y6Wq2cfCGc_4Zdug',),
#  ('yL2nF8k8y7Dn-M6JA4eyvw',),
#  ('lU1cFtgqdS-Yz317VEUpmA',),
#  ('6nVFYZ99dMy4qnDcler_jg',),
#  ('D1kxEcTbVdwd3G5C1LYAjw',),
#  ('qYb1ITEgz1tc03gdIJSrfQ',),
#  ('OEd5RHZ3lM0PCkqYXZJ6dw',),
#  ('uD88y_TZSCSi3xkuWu_8wg',),
#  ('-rphqFuHAKO2poZF1RHn1A',),
#  ('AptO1Y8NpRla8nbRK8R67w',),
#  ('GtYs6kuONl2SPagmhuRhKg',),
#  ('KhopHxSwn6rQYQRdb0nTtw',),
#  ('a-s5p0UBfBp1kg4O5hLyrg',),
#  ('UESe9VrLWUCHcc75315shA',),
#  ('vvcnhViCOxOTCTWIkHlCuw',),
#  ('dwpSfZWXYnuRg6v7FmCrPg',),
#  ('R489QRPFe1rLSBeI5c4scg',),
#  ('D3GQOVR9MKQBt_POvROgtQ',),
#  ('9UuC7wdMU0N1S6ViAtpuDw',),
#  ('K75UTsSK5AwrGtCx5yoavw',),
#  ('BocSTAYg8V0Jn0IBpG26pA',),
#  ('5rVTrASbIR6tFo82xz9OKA',),
#  ('1vJWuQ9Rm4lQq0WL61wdsQ',),
#  ('N_fjnSwoi9QSN1_i1strtA',),
#  ('xugfgNHlFCuo7C_8WhV7mQ',),
#  ('kCfk0g1_SVR_2q_xVe0waw',),
#  ('bdGcqiJierloZAskBy8OEQ',),
#  ('p121hnQFWV1YPY82Z7NADA',),
#  ('d6fnuCeDj8FCrV6M-YzSsA',),
#  ('vGCYtwPKPdqvIrHG1o1iqg',),
#  ('jOobCeoSERjqPA9jtFnhEg',),
#  ('Q4jZXWeH-FFUgj-i_tYkHg',),
#  ('AL_CuRqvkCH1h_czuLPTpA',),
#  ('qO6gZWoVMg23uf2xziNLow',),
#  ('SyQ0tjkHQe0UXyDRmo4sIQ',),
#  ('rGxhn6FYSQztzXMouPuEjw',),
#  ('1355fpXlKnj0O49dDE8u1Q',),
#  ('T6L0l4OyFaOC3iLfFDpyYg',),
#  ('PMqPQh4JLxjisYlhqifzeg',),
#  ('6YM4sTvinGAmPldrJv3G4A',),
#  ('PFrqcAEFJ1QNfUjlxYz_5A',),
#  ('mut-NtsrMsR_B9fXBeUy3w',),
#  ('uis6vcPyUFHb0FTGy1zfRQ',),
#  ('P296OXS_TPa_c_pP2GsSdg',),
#  ('GLzJ-DWZQ6tn1gjtI_IhzQ',),
#  ('kW8wW3yJBUFn8RVK9dQFqg',),
#  ('Wa2I7VS4Saslh0Xa--sGdQ',),
#  ('dcmuXaoHGbPRgnASR9EHVQ',),
#  ...]

# %%
biz_ID_list = []
for biz in biz_list:
    biz_ID = biz[0]
    biz_ID_list.append(biz_ID)
biz_ID_list
# Out:
# ['kmj7FnZsKPPH3psbR9tX7Q',
#  'GgvXfu8U80tcrxythjpB4w',
#  'TlDcvf1cEK2im6e4AFYe3A',
#  'npgq_up0_puDV5jieUza-A',
#  'Oi85AYz9-Bx-9SBjNf__vg',
#  'nuhFcWqgHBwmgwlbm4rI9w',
#  'Chuu09nqfEQbREmaphoOuw',
#  'FK_6tqTQuSkadiWQ1w8ttQ',
#  'nkUwnPPYmCICZ8nYCu_twg',
#  'XpY0Cxo_Iw2deqeY6zsNOA',
#  'tGtrhu0YDGkM9ECrYVz6xg',
#  'omwcHHgdgUJn-W1b3i78og',
#  'Mc17IR6PG4iZLmZzciJEQQ',
#  'oECxp7RoWT2QArWgqpwnMA',
#  'x0bjd5AUu3ASzfjmht2IYA',
#  'c_80f3N3NbWDX8RnvuM3Xg',
#  '89VGtFw9HZASM0IdnSEeFA',
#  'KjSI9xkCFTrRRbHOzCG7xg',
#  'PZhmOvUx0HrdGvxVrxTJ5g',
#  'b1ziC3xpS5Bb9PGsufBYAw',
#  'NqL3lVZgh1pz0tVaZBxkRg',
#  'vxNBDgBMP44E8DHuqj5z6A',
#  'dzvqCMHOsvruyOZZ8wSnbA',
#  'I3-EsRgXDcLx3OrlACCx3Q',
#  'qFJcpI5TOBQkX6BukZqUVw',
#  '6-fZD_ZzKJo29zapElbOZg',
#  'HcsOCtxnSpAmUU0EC_AGMQ',
#  'JvwVi-ZOfGKQEiezZTCgEA',
#  'PISWOLCiOj47QbZKm-F3tg',
#  'cwADiq0xORmv4QA2jhu-Pw',
#  'fiLGdKwhkvK6pZ3E_GjHmQ',
#  'qhjcMZivcYfr7CaTHkiXXg',
#  'P5OZCF6xChJtWNrjNFBBRA',
#  'gbRr9zRxpBtBLum9kMlxZw',
#  'hW_eQNgyPkfwAH4Gq6I6LQ',
#  'Vi_qAjnkRk4kCaMpx_-Gkg',
#  'Vwy58_3fyh1LwcMCFGb5vQ',
#  'Z1WcVd9DXCzU5az3PueunQ',
#  'Ai7Go_R0snWuiCL6rbYIXQ',
#  't2nv84yKVqk0PwsNTjBcUQ',
#  'NT2cSYhGgiJ-RgjtuNj3fQ',
#  'Bl8Z1G6mT8e6v5Ghr8P0Ng',
#  '8SDiypaoRC4TvrRz6wWRmg',
#  'TQpMRElRg2cTKZI50W8Veg',
#  'LvBTSQy3Zdx01WTKIr4Xrg',
#  '0QMXNHybK3sgpB-B5RvvdA',
#  'tH2owtqitA7hv1A2Ay0ZhQ',
#  '_Uu-HDdYlY9Eh5OqMYZezQ',
#  'ZvETO2Xbo_OKC3C2UiINyw',
#  'Zhw2qXOa9EJ5l0g6_QjDww',
#  'umqn4kMNmT8WKsuucJa1ww',
#  'dyoVHWTjlXlpr2kvpoe8_g',
#  'MWYIpLkfdv16R3amU7oGrQ',
#  'uxqguAr0IGjnI0C7FzZ4SQ',
#  '93AmVm0EksvVCR2MmIpBfg',
#  'NRZ1lxX2NZFOkC5CUHmJuw',
#  's_Jr2C-y6qluOh5raM9ttw',
#  '-E61k7Hh8oBJr6tNusW9Zg',
#  'MqHSQHanYp7x7TeQsw6irg',
#  'lSuCuOyvx2KL53r5jazj7w',
#  'MNmfii9J3VXy1G5e-3ijqw',
#  '60bHuvpb3RCcjDMWXTxlxg',
#  '83hjUA-b1Z9-Cg6JLQVaGg',
#  '7SabE_GzQzv61_xEQkYqWA',
#  'IQBAamxbdosKVxcQFs3Oyg',
#  'FAWfYKhFu7ctGOXYzbV9hg',
#  '8gkZ0XjzlWD2u19C6u1Opw',
#  '27nl01iIVzjPM_WUBShHQA',
#  'M8q5ZSIw5QRcmGyutY36xw',
#  'Jvgdn5qhU4vGNz3Ey4LadQ',
#  'OPBkfRPTvt3jpnwrq1pNMg',
#  '5Sc_YA2cjE7e1gYD3vm-0w',
#  'Xxpcpvlo8WwU4mEt7gYV2w',
#  'JJV3SiRIsCms7w6gO4Bfww',
#  'w4AOqcjuZyCYR_GTYd7XqA',
#  'cpDdPlXaMQpEfiraL6m9ug',
#  '7SmvCXxiv1eyu6hNSBl-tQ',
#  'Q53UIw2q3mXg3In5a2Cd7Q',
#  'IyQOk-m1D759q5600b4NGg',
#  'M71vD7M5Fyl3DPQ_rxGiyQ',
#  'oOTlC-enAQx93E3dJFYNug',
#  'Z8SXRePdS3CxgEDVk_nDuQ',
#  'i2rMUNgJTDAb2qU9GMOzzQ',
#  'qCPe3hDR3eh4RGQuCnX3Ag',
#  '8K5iq2ifYfC6GDjKL783-w',
#  'xSf4w_C2j2vPizDuDOIjWg',
#  '3s1Globxm8aqVaJORkJ5AA',
#  'jFJrpdkxUN0Sx4buzaPHZg',
#  'VdvLa666NuiwmhLMs9Q8hw',
#  'zUnNfTaf_sjmr-dxsFi3mA',
#  'ml6qehFRKM9Cd_IhUK2c8A',
#  '-QpGdj4IEj64wKGacOXBMQ',
#  '7HagB-Wj8E48ifbrJkfHZQ',
#  '8ffaBp42CKGHYWzecfZx3w',
#  '_bNCS5YsHLhx98OAb904ZQ',
#  '0SO-6VPWZNZwMoKgnFSBCg',
#  'HKTl-0wTCKfjpRemGAzwFQ',
#  'gjabMrwiNvvsrtIzb15hMQ',
#  '4QUmpPjbfqHFLjXGNNB22g',
#  'JS59cnDBaCLAis2VRDjwlQ',
#  '1aTKB4RF6PAG2r0ooPCS3g',
#  '4jQqBNAYLezWmOA4bV_yqg',
#  '_ubMAZ8QpuHWQymbzLTW6Q',
#  'FXQdHM1cFKSDZXud0jIl9w',
#  'BH7QCJsvNCqNIJN057ab5A',
#  'F0gpuS5a6j2Y76BA3zsGqw',
#  'jdBXz7YphqxZ90YPw6Gpjw',
#  'AtnOT0J8Y4vY2kO0XnW5eA',
#  'XszF_PFYigJbkkMq6cxtQQ',
#  'H0K0iDupOr6u4KUm3_-Pzw',
#  'UfHQlBhDFffiT3kXeaFt7w',
#  'vWRltR8HAaOJ1PYWCbRfVg',
#  '6NJf80CYXclDmsrP0Z26iQ',
#  'qrbSKme6vlJglwDSk4tlSg',
#  'CiZH6SwLIwWwu6cyDJrPvw',
#  '1Tl3PXf6LyNSy6wYSbVvnw',
#  'En5aFve954HTYzaUjyoFSg',
#  '5wXahdRlQBBB0wIB2PJkgg',
#  'dY_tjHFbnhE6VGNqsyrtfQ',
#  'YgKiSTpw2badaYgxShBjkQ',
#  'ZRzkpcG7W84b0ukYwJQCng',
#  'u4TzZEjmzrqZpFcea5LD2w',
#  'SF_x8MNc3SI7PO6SaKmbuQ',
#  'lx4saYsRPK9kiCskpUAaww',
#  'EC_j2Oub12S5R34suUQGkw',
#  'vXBr2EPJa4TBkXCzY8aJCA',
#  'FCvutB7sglxMulXqoVASSQ',
#  'L-FvLWawzPb0YY4Zc4NsSg',
#  'cgbgv8DRHtOQ6-99UWRWUA',
#  'UtYrO3Yuf0aOxuI8x_nLmg',
#  '9fmI9NE0hsOnKeUfUETYlQ',
#  'm4shaTSFeHEYTZ5sLad5qQ',
#  'ZKpyVsGCqVWDVr2nl_agEg',
#  'Lw4UVdRnof8wLwg02dP6Qg',
#  'XdNdzhii1sCW2jh6PIf5Kw',
#  '2rGQmYEAp3777OdONqAeVg',
#  'eOqXigYmWoIRxwnCfLFDyA',
#  'QARBImstVuDE9c2lQDCJwg',
#  '9vdtU6X6Bl866PHioNT2PQ',
#  'ER3saHOKFplcgD79DA49EA',
#  '8QsqsSxnMyMjzFkWymtQ0w',
#  'bQf3u6mS2G2fXKM-3ev7XQ',
#  '3GuipCTZ2BmBAazKPEKebQ',
#  '0xXYCKOaZ6joxZtBBgi1Uw',
#  'R5sTa-S5GBwxTJF6xx7XkQ',
#  'wG96y8b8JISNmdATA_pnBQ',
#  'IU2Rc0EAfEp27F62RrVgyg',
#  'ikuE6l0lWOz2N6Flv2ZCYg',
#  'sytPIeQiGItDv58N8Iu8Xg',
#  'q37HTbcdfogO73dlRFYftA',
#  'KPlz9cT-4WWfxDN4d7bHTw',
#  '6LR6FxZOcqzK-5Oe41Yqag',
#  'UWJrhAPBk3tcqJa-XszGRQ',
#  'W7XmLlHOvF2MpE252lnL9A',
#  'vVE6pQFArPDeps2FhhkVxQ',
#  'ryhxaXvnYvDJiNYQqLKFTQ',
#  'PFcPwHy_sa13V7Kio5XpSA',
#  'xZNpQn19vydiLvKtDd-FOA',
#  'mrz-vVtNkx4b2PR6UbHg0w',
#  'i4Vd85r8Py6U2iVlDPaYmQ',
#  '-5h5zs6EHDEPP7xY4C_WDg',
#  'ZhainggV-I4ziYfoHEUqJA',
#  'aAisMje9Gxre1TLvxkOgAw',
#  '5HgQsbEhK2OKtQLhB9NNNw',
#  'leVqeIg0IAqHWij7oM3__w',
#  'f_Xot3Ev7E013MEnJxB18w',
#  'Mt1O4GaqTO1OTg3vkXCvDg',
#  'w2NWa1j5SOyFRL4AuABRbg',
#  'DfKCR99SUGHbGUFZxpt09g',
#  'Xx1oRsCre6AUyx_Y3n4Hbw',
#  'KZ6KXbwEHUdmHNgiMK-8-g',
#  'fbMRu1FN-th2cGZi5zTLAw',
#  'YQXqClu-AlnAnGsmpxBhsg',
#  'AG3irsDyjq_4c34P0ZSbEA',
#  'Xob5GU4BlAuLSwZfpkhHJg',
#  'itT_r0ar_h7h2KgfHN31XQ',
#  'ZKeIGumlfLE-z2d4Zql27Q',
#  'EEC8dvpMPaAVjS6U3sVN3w',
#  'XpgHe-61AkG27GBzO_o6Nw',
#  'K07l7V2bqOaHQI5aERyoWg',
#  'BwBefgCu3ktbrMoe4d6nww',
#  'hMOTk0tX9AFh6QSCVahbIw',
#  'gMMEW-Hqc6vpzkqUVPkYcA',
#  '_xCZHH2mA9-E6gZ13TNjJg',
#  'Q_QH1OLH3SZvXnGb4ivY0g',
#  '5KzA7MSotsIFDsNQLu1uGg',
#  'eawNf9PaP2wQ14acGvfmUg',
#  '1qliCofGq88Ru6CxiAkf1A',
#  'Q5XpAtV-b7311IBwhlXjeg',
#  'p0cucU3YX4RCVc4dT2dqfA',
#  'RJ8uhFCH-fMEKnNQo4tX6g',
#  'NFyesGjxtKbOMantBuqKIA',
#  'C9VYjW_YI70zKH6i2akNtw',
#  '0mODqlC1txeFM90X1PY_KQ',
#  'bOAwqQdCvatXwSXqh9f5Gw',
#  'wERjTaukDFZuBifomLp6LA',
#  'kNuVZZnKwyzn1sdEMvRmrw',
#  'doESmLbUOyo7fdsDdH9Ogw',
#  'gf9yd5b_4pavncmznZEYdg',
#  'NhDEqzY_WVEB_31YbO7Vow',
#  'GFAHMQBe06-7FNOOjoFZCA',
#  'JXQRVACagbIxMwWQLOC8-A',
#  'd-QfVdNPKppkiNwli6Iblw',
#  'HtxVObOng0hOfLIAPFCDmg',
#  '_N4HYoldjdmTWTXkgHd1Dg',
#  '0k2gUhV6Js2MSqMXh8LgnA',
#  'b1ZLTLqcbXQ-JUb0kxEU-w',
#  'm-ZtiNHs2-gV15vJB33Lgg',
#  'm6iFADo3nqd3S3jITLjo_g',
#  'Iy1NmO-GsQwpmivToNgBGg',
#  'b38EEu4DrkSJIvBWSCdEdQ',
#  'CTPkr_K1E-Z1oOLTR_kwbw',
#  'Rwqpgsxbal1YSFKNXoax1Q',
#  '07KhiTvE_OGymTrqKR1F0A',
#  'GqVPqAx45npdh6tfJwwHPQ',
#  'YznZC3kHO2v8J5uxASReVQ',
#  'QALs9S5-nQU6IF9ouACj2g',
#  'XejVF7D54ahjhRc5VVZMNg',
#  'ACE-37NrrV4-uhY68iuERQ',
#  'KeYS2QoDGvmJw3NhQNeLaA',
#  'JOBFJM6mbVJ1EXkUC0yelQ',
#  'iVrmx_UBQkUxL0H4N7Oc8Q',
#  'MqkjXdE99Zbzp87nozBs7Q',
#  'jBTwA-Ld7lcsZa8IQ0zCkw',
#  'vyYTecqfoJrFbgg3Gr4MVw',
#  'pDnURP_MHVySCnrldBXkXA',
#  'aWvo8l_vq2-7HmcEnZpZMg',
#  'gldnBGyzgLrZVXGJtw_-vg',
#  'JqqFRqqMoTkOY856mcfeyA',
#  'Zz3ioAbCdY-uD0ym8yYnJg',
#  'TkvGVx0B_ZgiKBKmVwdSzQ',
#  '68kLlsxRfOU6NVZ7YO7ggw',
#  'DtB9kPpbgpEVj41Uk514fA',
#  'rKK2XCDx4FTJoOyHuRK4wQ',
#  '5mk_kStr8boSHQboN5Ldpg',
#  'cO9ztQr0LuBLE-_bDw0zsA',
#  'rieUix21JovG0n1EpZakRw',
#  'WCyT3VGfbzWlZh_Lmw9RbQ',
#  'Ysfx4N0mcM0IcIcG2PSn3w',
#  'Dzm3FU5DQqrv0qCT2y8lfg',
#  'H496_d2t2HQmjfPZZLDZ0A',
#  'VX7zndWYe8WT6dA1bGzNAg',
#  'GUPjVv_X49sNhR-5aQfR1A',
#  '6WE-sR5u5X3BmpBdTCAgvg',
#  'Wa73h2DImscvlLLs1WXeUA',
#  '7qHIaotRL0DZgHSlu_X4Cw',
#  'EoY34QdOzFN1-gqiVnbHNw',
#  'qPQQTvOeoBjHtCOVbU2pFg',
#  'vuvIJq5-X00XIWZQ4iEBQA',
#  '5MpHrLZWocROYMhx8eIH7A',
#  'IbUJkh-yP-tuaVgTthn-zQ',
#  'YMceMR-Hk_Vq5vbUGoetrQ',
#  'NgGttZxUm18VJfFmtxT1Qw',
#  'zhUK26CLZh2R0nzCmwR3Jg',
#  'hhX--bDltqJXw4oxoOoeSA',
#  'COxB_72tmQu4ILQeU0OUUg',
#  'XkRq013sWm6L2qcRhhimFA',
#  '_VNQwsQk3QTjBzMrq0xgBg',
#  'nUuhitWt0KHCAletmFMZJA',
#  'uUb8lDmKEUt49kNM7kbwBA',
#  'M0J0PaOUv-H8OGWklvb5iw',
#  '-3g8fnJvg6RLQ2z50zf3iA',
#  'qbMYHBtuIGK4zpOHGAKyjA',
#  'e-CDVUrRakfj3WLF0m4QLQ',
#  '888lMk7xogBx3q3TSp0LQQ',
#  'LHY_vVkMp-InRplNIYzepA',
#  'CNujAn67RSX9RDwtxGebNA',
#  '_EsH83xo69NljjvU2hp3Bw',
#  'Dq5p3zia8jzsQFYNRLb9jw',
#  '9GFu-jtxKpItgw_bXrQWEw',
#  'yDOs65_lYbLBjssZOPTLXg',
#  'FBXl7RMiVSRvckxDr9CQEA',
#  'nd5p0XqVlmNrfTLQMIRIgA',
#  'WBzvDkSufsmVTAONu5raWg',
#  '-32-_pPqGEh6DjDfPaRaEg',
#  'gxLEKhkXZtJ5s5S7I1SS9Q',
#  '9xg6Z0JsumsCWHQEiYLhtQ',
#  'ZSIFK0NEjySpLrQ_GZX3PA',
#  'ZHGnWKNnYR4Sz_NvI9vQFQ',
#  'o7PCnPEw6tJzNvzhy673AA',
#  '0oc1iiRZq6skSuXtk51y2Q',
#  'O1xO33gLrQej81SKqA_wuQ',
#  'EuKG628s61ruVE5mwth1hQ',
#  'IHuNdHddUgNIE6sp17XtmA',
#  'D0GDxlHI29y6M9gVNhUR2Q',
#  'VV54t7XWqaC3-FZRz0jaVA',
#  '82Sm6A3V4kh3tLzcFQx3Wg',
#  'S0KhMlyWvrQmd-0eZ7acrA',
#  'W7qIkcSL6JzD1Z0b3OUbvw',
#  'ca28NmQJZzn1uMwDhRrzmA',
#  '6S9EW17sUAKb-qgaPQw-6A',
#  'NqlGsRCK7HTVhVKb5t1cWg',
#  'Wz_ulFycNNHGEWqcUDCZvw',
#  'aDAe1J_w9ZCT6ymhalD2xA',
#  'k32a935G7tNF4H6hXhp0kQ',
#  'W8J5csn0EtyYL6GYWwXUkw',
#  'l1W-iGzrj0kD8pff3gT0rg',
#  'pO8Jjcm4G5CCwNC2ER8mwQ',
#  'U5tnyPM-A3x0NfMd0Mbt4Q',
#  'g1aeCSBn_4SDB20DyBFUfg',
#  'bTV13BipswAdzbeflUg7jA',
#  'UbO4FG78i05dk7REvtp5Wg',
#  'OL0k5_XrtlLgqeOw88i4yA',
#  'EMOViczrCwrMr9W0KExMcA',
#  'l6mcDmZ-opOLBFNRA5dncg',
#  '-ew5Bt6l26xfNK3yovXfhA',
#  'zHyc1HwafQLqbCAmRNAoqg',
#  'oa-DRb89PdHAwcykqD3Cog',
#  'VQA2rTCXl9R6j7B9_klGSw',
#  'dhg9tWiKlwuoL23eIEel6A',
#  'MctD7EmQ_ZKLnj4gR5tyDg',
#  'oDJdR1Eqq3I937IyMbKmAA',
#  'diqzaGNdc1XGTTMT8iWacQ',
#  '8Oh-jomXxG4jHyTuQJbFmw',
#  '77wk9AjysLqoQNPy52JhGw',
#  'gXh0swaIaVIc2Sl-_4atxQ',
#  'VLCNM7kt9yd5E-fKr-mLZw',
#  '5NUcgiLfu-JD6_dhq6Go1g',
#  'ymWhicwFFC1rafiEKzO7Fw',
#  '8tb9nEgyMwTYzFx7Nfl2Sg',
#  'veLphnlX0OxM7XdF00OZOA',
#  '5OWYXVE97Ebt9KbLt7Oixg',
#  'rIv3dqcYasq5lY5Mcy_njw',
#  'zjFaGuRCXL5j42f3PVKq7Q',
#  'xbBwsqndTM8avyNcMSTHsQ',
#  'oAwyvQiSWGoGY9ksh4yQRw',
#  'AY3JcFcANFi4CzjCzWHOzg',
#  'MXMnBjSKXU3ETU0AlvCBKA',
#  'oYln38LaaxxHMBG47L4PKQ',
#  'zhfYBNaA3RotkghpOO_uKQ',
#  'M_6BIcBpJkMw_ctQa203-A',
#  '9TxywGOFqRBtvC3LAjMbhg',
#  'AuFy7S5Y_6vfmtIx8Oo-yg',
#  'mlb2tClmUKitNwgd--J68g',
#  'Qdj3dXWvHoLgawlSElf5vA',
#  'v-782AFTTK7iziNai8O30A',
#  'b8uzrCo7aZruVMhi60KaYg',
#  'UTygP7lxfh4s1Hzvc0iHvA',
#  'Jjwd5LXhmCRYDKVJdjXagA',
#  'TvCiQb8ZrqZrSVHQ21QHhA',
#  '1RCxpKi6GmBYAKKeOKubQw',
#  '65nqrCNlRvvFRFze9mDiLQ',
#  'cQQRNCBiZjcdM88R-C1NrQ',
#  'sj2btVBFaeti6mHmIb9m7g',
#  'JPue4nE5h_oo9TAMXGINZw',
#  'G0J3zXl5oddtTs5iMcscWg',
#  'TlOI0p20dkiPaiTPna1ZZw',
#  '3RU_FJf-WKvMDJEsZ6j-UQ',
#  'HfN6J0K_ZftLLGSIeBhYCw',
#  'KMOf6kf-w3ewo2o1_IwOXA',
#  'dxyu9dHXi9L39GgzMno2gQ',
#  'tt0xNkQNplbFy59s4m-SSQ',
#  'WFjkw9bxQrIDtzbvSB7iEA',
#  '-6D_psNt_6CfFhsPKEKscA',
#  'PZCo4Q_chnItcIJBe_3y-g',
#  'i_La21PmC_wnwbjXZd_RDQ',
#  'wxMPRmK5AzN5rg81Z9lgHg',
#  'fDnhuobq7nsIl-VAAHYPIg',
#  'FNwTfbah3O6jH1CmiugQUw',
#  'ZtAPtRl8mE8XZsmFLM-k5Q',
#  '3mufQ1Uzs8GDcEn_cTLYBA',
#  'Um_oY3yR9ZJ_v-nRFD3jxQ',
#  'Oic-EPN0QJUaDqgOJaD77w',
#  'LfHdpZr7RwDAwoepdAvibQ',
#  '0mbkviLYAktyYzvckIV_yw',
#  'Ls0gkngEU2BDHCxuPUPoGQ',
#  'n-L3DnnxnqhmCHuqVZ3tjQ',
#  'hd8zSpWlNBHyklwjRSv7GA',
#  'apfS6ZENiadjSQmVYKKh4Q',
#  'yTE1l9xVuZt9-NO1Cq9lSw',
#  'U8rokJPppWcYNw3D3zk7cg',
#  '3L34j3Wq9ZO4a9K3qOvqPg',
#  'YAGUbV2eRgpL_tZrWTs_mQ',
#  'czEi3DNqcv8jNWNAOcXpbQ',
#  'XMjzCJ4KJK5cdCRYJM6kWg',
#  'q2esJfGwga6N2ifO1qQvFQ',
#  'Q5OJc0YK-yGgTq5F8cIKUg',
#  'p1WRXG-DxZkKGLIketJyXA',
#  'gmDS_5oSBLZmWLz-34UrZw',
#  '5hGm3Us_8-leHVEFlRIU1Q',
#  'S6XvyJmuCw5YyCQKjL0o-Q',
#  'pDwaH8t0a7Lxlr3Bca0Dxg',
#  'pFDy8BN_6tJgKVPnihuNVQ',
#  '60gn3T1ilPX9Q_MvF9YAbg',
#  'VMSLI9M17mr-KOkjSnOABw',
#  'ap8Roi9sWXlwHsrZGV0o_Q',
#  'Utcu3PrZG2wteeOnyT1DkA',
#  'qY-S5lWjyXXAEFTGFDE_8A',
#  'VjMNsGw__sx5-7URk5cZQw',
#  'gqNoUXD7gKD5odz5x506pA',
#  'GAkOamL6wp4qzo6tZGe5JQ',
#  'HCMgIu87TNV0r_hyoLeQSA',
#  'oGaofHQQgqfzGDaYGJuOQw',
#  'U7VEPU6W9s2qFFsnIbXJ_Q',
#  'QvDGSma_7uTpwYVZSk0O3g',
#  'bU3WKckYWhNyPutL-uQbSQ',
#  'tBFHxa_7s1ffGdgVK1EjTA',
#  'ZwvV_RJv8bTkV0bzrChizg',
#  'KPxlMp7Gcv8_sJnAyv_rSg',
#  'MYKn0v6dWdLAWzY4EFtcNg',
#  'l5wlctBzy2aYrprNBdR-LQ',
#  'k4DwOUMQgpEYLjsIvSIoGw',
#  'fv9iFlhSc_sxxrQqZcsE4g',
#  '3slXoNiNDmRVyUP8tN-1TA',
#  'g-sLjjT0ErZFq2jhfyOoCA',
#  'cgP5YnTRzPW7s66Pg0b5Og',
#  'dWNE-ysBg2QphRuPgvy2mg',
#  'Ed4HYd35dtK41BqtYFoCCw',
#  'ePeWawx_RqeDMvzJ6_ZsBw',
#  'P8IKtsq_5pUccneLPbZODg',
#  '_zfp6btTiGz_ZSp0NI15BQ',
#  'oNtK36UuAuUWYoE2CTRMnA',
#  '2UPqLPZTCyIvGtYfOnjCTw',
#  'jaSgJPjU6KCJvqGKvqQlQQ',
#  'xFohvFeTiCHhst8zJaGi3A',
#  'kA1lTl1ncNR-235Xxc0L9Q',
#  'VWMmrMQjD_Ltzd4WZxlGMw',
#  'QKknMvCRccDncn7HYwEZFg',
#  'GHLaOIWPwQVchyKUPWw1Pw',
#  'ZCeeP48lmI3kmvDAQnoy-g',
#  'qS-bB-QGFn97i_8Av8lTYQ',
#  'JmvsOxnrsnwuUQIGXOeT6A',
#  'ArVZkLoV4ABBfpXXx1IxEw',
#  'SSpAjr5UiYamFVUQ3IEftQ',
#  's4bynq8tk8zfjAXegF6ZRQ',
#  'QjgcZ3n9zrFYN4MLVOetJw',
#  'jKfO-SoKG2jU0vd1CUEmfQ',
#  '68l0bBxOrqjt1bkeQeLSzw',
#  'Jfw7itjMoj-KYobi32Qj4A',
#  'yFvGJCRxVwvBBRz42R1ZiQ',
#  'W2BaBRFg4aFFmrbKiMWekw',
#  'LePniV3t4G9Lm39hSt65Cg',
#  'z8bpiZnQo9JDOSOBJJwltg',
#  'egg-zFmHmbwHpDCwy3RZ0Q',
#  'z1sXsz7GmnXIj0jIog88Mg',
#  'Lg-JlHW40TJVgF7OMmBhVA',
#  'iy4N7gk9lv7RoeQqa0JIVg',
#  'UWfhvkOLUeFz-_ISp11duQ',
#  'L1Sk_xu3g2sgjSYorrFsaQ',
#  'Bf2rbwPm-H7q289miZ9tEw',
#  'JQmFbXg5teLQ1Ir41GTNrQ',
#  'G9fgfgtacSWTXbM1DQxVgA',
#  'DGsQi2VDOC1a3ZZv27Qv_Q',
#  'eYITfkgXy2wlrCBW9yfTDg',
#  'KPoZZNSoYoZ2zvHmbV_vww',
#  'I9iNZQtWaIlP6yyql9l3sQ',
#  'Wt9rwewIhjpAk4mf4pcNrQ',
#  'XdupBTtz63qDJPu_hcCwdA',
#  'iIiM4lBS4sc_egRVrWq1ZQ',
#  '8fZddu3UxgKzSjmgcR7xyQ',
#  'ryMWV3vfJlQUppEHTabS5w',
#  'Q1wJNg7Dt5sjD8miOnWffQ',
#  '2NTHYJ9G-rpCz3UiZRis8w',
#  'e60rNmVPYmrgeqaCj406eQ',
#  '7vmZVZKdGyiFUdQnmb_e5g',
#  'rdNBYJuvBomARtpJMPKVJw',
#  'ZkkItZ3aCh0-rG6xB_fxwA',
#  'uuKtEr15nMsFoHMUlO6AeA',
#  'yaBet4Os0LSSGeDLb4Psdg',
#  'KxGan_7T0KEWeSdvZUO4NA',
#  'cN-j9UNXsgZ9N153CJDmgg',
#  'mOhaio-zX-vmkWMiPZENpA',
#  'sNa_0srnUEARgcrGzbvB-g',
#  'k7i5q8wijE4HETLuwjkkgg',
#  'o1jYBEAWVA2_OfNYexqi3Q',
#  'YbYxYJ4XQCBvSTeB5UYUTQ',
#  'IHNfuyKaTY4Q-t3b1ZCZNg',
#  'wnIrQ08iCGospnk5S9_geQ',
#  '3TAtnWVfZbtmRmDVfOyXSQ',
#  '_W4UlF2kVBtJlHCaYksJ0Q',
#  'smolIT5CxfjOhXsn-lWD1A',
#  'OF3Dd17gq8rbCPJKpxW7EA',
#  '39r6jGFpLLWuJgBsi5ggkA',
#  'XolfCucGtjttWA9wo2aYgg',
#  'p9sC52CMmqIBzkNVsARTUA',
#  'Kim9Q4x5AiWaUgJ_hM8Hnw',
#  'NbmcFDFOKvPajcIldcZE8w',
#  'EGg_N3SzzONnon7YVr8OyA',
#  '_xL4VsHbrn5n1MFQHcUpbg',
#  'MlXwL_ISVz2Y8zHMcRXFsg',
#  'iUza8HO5Gwk5tYSgt4XHGA',
#  'SHNUJF6u-m9gSs_oE0tEHA',
#  'rtP7Llez0PRtnQ6PAuzgVg',
#  'FszFOnQwr0bqnDDOrmYdyA',
#  'R9KEkeDjk4xQjG_w2PLjew',
#  '-nhSQy8OBWfC-j3MVTcOBA',
#  'W906xM1gjtr_w8H5IEjrvw',
#  'VYGcpIQIrFgPaUmjOilD4g',
#  'zi28ixzR5KbyduRo0WPQpQ',
#  'QbgvROQ-r0HfTyySG2iPMw',
#  'UcgWvGtNiBNQk7P9pqIAYQ',
#  'SFK_A_wYluSJqFdrm8QXnw',
#  'ndKRNo8K37PPCoG9yDQzeQ',
#  'gWE3SVepYm92XQBVCs-Xtg',
#  'AY3H0k0ccSw5xWuUpe89Xg',
#  'SW_4ulIIDQ52y_9rWv-7vg',
#  'ypeRKaFOXoO8QuzAmmoPVg',
#  'iudyAw_m9rNtfYzUOcCbvg',
#  '7Y48OAp_57c9FqWnqYL5Qg',
#  'SU5xh7FWOHyptU6DacPyOA',
#  '7QN3-rRh86x5vKzN2H7Bzw',
#  '9_Umx8fGKAH8CGp9CaOe5w',
#  'KStWOAAa1SiaX3wQ3dvr-g',
#  'Cfrq5bj7WksLx3LBzp79DQ',
#  'r4nid2qn8rNYWOaDTCvuzg',
#  'gH5f4yBxS8TvOYAbWPUsCQ',
#  'PLfKlgh8uA2MHO7i7amT_Q',
#  'DsfuxLSpBYzf-JcuAm09Iw',
#  'UA546ImqzJEt6uD1uD_eHA',
#  'IjiUHhvzuaEO48nDeRcoRw',
#  'pwJ12SSn9OZKimwFg64ngg',
#  'KOVR3AwwKvU-T7bSC3FnUQ',
#  'me34YrxS8rto8Lxz3UJGew',
#  'fnn5-INgblboZ1zTt3Ej0g',
#  'l8byU9GQXHsuKDnWZuMtUw',
#  'uXyYZvA_DelRWHtUxNpreQ',
#  '3qAEYqeGnPqMuXhDZslh-w',
#  'oj8GEKxaEYTp4PNJ1YRjjg',
#  'bawpBGGd8tLR5FYgn4rcEg',
#  '48hnysGBvtK5oUQ5TKk58g',
#  'Mlo8UphMkoy9XMWHVgZsgA',
#  'LuaOfuKRS7kSv92UDxn--w',
#  'ccqFI5mr0UJPK57YQdQeCA',
#  'gwO-tYnFozycQBPauVZSJw',
#  'npZ06P05N0-Upu4dLZZUSA',
#  '2QDgXG2MRq48wlXq7Hk0EQ',
#  'Qtx1FgKKE_UCsvUYtteqkw',
#  '3Qwmum6W8JI-1rG2wTijfA',
#  'hgkSSSs1_aStDZjLzvKKEA',
#  'aNdeGo_j7zuKCTLhNE7WaA',
#  '9tyyPS9QiBfaOjfZEOs0Dg',
#  '84IN6lj_RtBegQNxeQgC9Q',
#  '1LYMsMDDi1SFghrp09k-ig',
#  'USLNKQipejpaQLKssBWpDQ',
#  'mV_0wroHy1Ihvblz3QqKYg',
#  '2vN5p0SoqDGPcUCM-79nsg',
#  'IrkovwdJAHLwbufSdXFPZw',
#  '_QgoXmaFP7CRCD_HjTjSLQ',
#  'D92dGXE85kotmmk7f72sVQ',
#  '2j3zKYggoh6Mf0G_md6C2Q',
#  'srwj9K7fp9qp0N_kz5wLVg',
#  'WVKxxxXs56Iz7BRm7l7Mtg',
#  'CVhGfSh5KaT_z_49qYFcAg',
#  'NlMbFXOv59hD7eMZ_qSgPg',
#  '2j9zrcz1kkpHoMGzxYKVDQ',
#  'dGQgfRPMPkQMsyhkkLmMmg',
#  'qNqLENNTgVQgyneh4Voggw',
#  '8K26qDnPvXWUklqLra7DaA',
#  'GLX8AFOYxz95LInYKZxIxw',
#  '3pWKZwzDwVHsB0dXOsWd5g',
#  'NdjEQBqdoqRHqQP8C8EY-A',
#  'vLrrFhUZeUfaEEJZ82Bqmw',
#  '8HZER7QBhoyreaGwPqRcbw',
#  '7lVQuZu3jOawNCQag1mZMg',
#  'DEzsN1twefctTDWf3Wm0CA',
#  '8aKSgzolNkGmkZ16DuVj4A',
#  'Iod9uD0fnk4jygcRmjmRmw',
#  'XsxiQKDerWlCRySuK9esWQ',
#  'bQaQX2WbWmazPOeZaClHMA',
#  '0T88HCCZjHW5AJnloL_UDg',
#  'hqecZgNzDzwbDXj4aOyX6Q',
#  'RJR0F9S0etAXGDGh-f7KBA',
#  'HRMl7D6Lb_NaBK96iOj6EQ',
#  'et9zYMicnXw4amGgX4SbTQ',
#  'PVduTjlmPaVkIDoJINZ1xw',
#  'hQr8tF6Cz1KhECQiXOo_yg',
#  'gz2Gmqzirvq-c9ra3QpSzA',
#  'GFaJ74Oy3xineK8OaG-HlQ',
#  'TqhJxOgdm4XRp5vlAZ1Mag',
#  'zyhahWLIwbI1lzMD7nsd-A',
#  'GQ4OLF4FdtETAB8r-NwJ8w',
#  'hCjUI_MLOPznBhADGtwalg',
#  'Nu_uQKKe7o6VdSlivfJfxg',
#  'EamtVYxeKpvCZFDAqHeBSA',
#  '2ztorhPf63RGjdsPZtpOHw',
#  '_Hh3BXS65Zlq3-RW47yqrw',
#  'd7bLampqjiR8R4SLYpbV6A',
#  'DTBIJW0o4WTeYjbOm7HDUQ',
#  'UsYM8qeZQV6yUhYu7IIwpA',
#  'ZW7o3JncC4EBW6cwcLVSBw',
#  '5dPgSjZZ4OG2BeM9X4EupQ',
#  'YKWJrXS23FB2M2b5eZEiUQ',
#  'VX792n5wt4_aZS1V8M2MFA',
#  'nCK7LNlQG4J5hfvDpk7zuw',
#  'p_CTWr-Gy2qUPhj4SwWFcA',
#  'OxS5vMAKiGxsv_HgUETtbQ',
#  'z1ZTJCagmBxCOT9ODRty5g',
#  '9b4mVJXf8GMGHg6_snLT8w',
#  '6bjqZ8sK3vVz5jojqIzmow',
#  'Zd2s-Q4CcX8rbSQUzuilZA',
#  'nmAfJhcfwXBlV7GGmPLhuw',
#  'nqh3fwnIO_4Eu_SgDvkwxA',
#  '1sjp8ORHPEp6JzeRhiSCag',
#  '106p3Kgv9huPmVBEDuZs_w',
#  'DjON-XXcdn_rxaHYPgJTng',
#  'UR4cr_OXx5wl-I6hNqr_SA',
#  'dotZ-G6DyoxBDOWKulw6RA',
#  'NCqxjD90_phMbhKIvR1f7A',
#  'MifCzYpxtABTL56rYrGBLw',
#  'n4J0A5sULb7SS5-0EnFFoQ',
#  'h5gxUQQU-VPx20yd1Eydxg',
#  'UOLZhCN3A1sQdSNVeKvJ0w',
#  'LAAShVb0YlUzFfAsq3c1GA',
#  'uH3vhK1Y6TrNQ5u8XeQKfg',
#  'yuOGuNFEdHrLRThrmPlZQg',
#  'gZTmDVMKSs3Gb5QZi_cj4w',
#  'GrwEzqf-3QaJXzQS0gawhA',
#  'ezXSAqUx5P0RCJowZ92-dg',
#  'pu2J2OqBicfCUE-dGAepAw',
#  'QxiTikuEsaAGmbImP7t09A',
#  'xNormhHFBzPdglzXi8pzmg',
#  'o4qhN4AmM7TOGJh6ARSTKg',
#  'JK5qxXoWLOIHnKIzxZ8ifg',
#  'm-nE_jmsIULoPQB2R_Lg3w',
#  'ytpspiwR-VJNdIlHK8LyOw',
#  'y-Ey9DwUZT0HWccYiUqKmw',
#  'Tk7_ZWvUqtWUnInUEj_utA',
#  'il8CzTgsT4v7u4227ZKqAg',
#  'Q0COuVM1nTG6vgiqlOmvEQ',
#  'yqbKM1_PqyTY2FZ7UeqaDw',
#  'rCwlWcmH-JXyaaFSLE-2fQ',
#  'mt29eW3lSG69rX9vDFandQ',
#  'yenb3OpLkWExqCLqfbggbA',
#  'Kd08jz1x1i2UAIAtO1BG5w',
#  'C462qx6YAQtlzMS7tZ6A7A',
#  'jaPUTqCUhs57lzPTwe0Pfg',
#  'OQtCXwdO7ADhnvqS-yJqXA',
#  'no7So6vxuH23WszXQVwiiQ',
#  '0ym4qVWjpboD4iC7g372xQ',
#  '3zgOtsf6KYwliNMJtwBo0A',
#  'BTrHqUhtKr8dRY7foHpnWw',
#  'QN5iE3MkXTtSQQ03bTRJKw',
#  'lZVi3Vwh8F6CT5i_sJvLWw',
#  'qKbVZYvOB6YnGGl1EBhJMw',
#  '6E_2VuENq2OwzM8E6ik6Xg',
#  '0zil0OKvw41ZUWJsiHwdQw',
#  '0U46pBYwbNAqL5tqiv883A',
#  'kJcM8H7fFUDqY1yNPNmi-A',
#  'JSJpOi4UqcSTUMufeU2Y2g',
#  'g_Z-ZPIGEtjX0qo3zq37nw',
#  'sKIvnA2rWrJd7YuOrO8hWA',
#  '0RJfjslFNbfMe8SRJtygrw',
#  'TUeoRgy-T9O0RGIWE3jpMQ',
#  'SibccDZOpLKtWk96LyGEHg',
#  'QyagCngFfzF6frlWnh0tkQ',
#  'VcD3kUPRlNj79nwI-9wCqA',
#  'CIKv9BT_aoATQFeBdANWVA',
#  'hSerpix0u5nlMgKIt3_Taw',
#  'sN629ieIZfYGxmvfeiPC6g',
#  'ojH8c9Icmtwcis4mmFySFA',
#  'qULqJf26IZwgaoG4kh6lDQ',
#  'sGBhG4s4dlCSeDAohfAIQA',
#  '4knwPuW_6reQsNXDOl0giw',
#  'EvU2sjvwGiW6qyDbgBpolQ',
#  'BazU_4ukUE1qw29J_Wc1uw',
#  'cmppNk4OhMPm2bKxu8Nung',
#  'zp8t-QceOC14BIn6W5xyTA',
#  'Ppi1A4d8Z_eZM71z-5dkhA',
#  'z2_T5XAd_cA9-yPZjHL03w',
#  'Dv2lphDoyxyNnpevmN40qQ',
#  'C2TzhDl_XFzvVzRCkzBWtQ',
#  'GBm2J3jjt9h18_tvmxgJIg',
#  'C2KUJyIbq-K7tomhyBkS4w',
#  'OnP7Oj26mp3KQXfjRhxhbg',
#  'X5DR-gwCEp10ocrMPxLo4Q',
#  'KqWQUR1hgxyLaoY2u_9pow',
#  'yCc36IWanCf0AmKEQBlELw',
#  'jnJhqLOWRTdeZAsizFwkrA',
#  'UeGg82SJYNQ7OWqjY5DduA',
#  'oLSEPDs8fAjGqEboNaOo3w',
#  'U7oW8dsUovqcaKm6GoI5tA',
#  '7lGVLGqsBNKueYMHDLXTZg',
#  'lFRj2FCS0hhC5Qxm8bFdxA',
#  'alM6VpVqcWAhcBnZX_aknQ',
#  'mQmhKsGnD-jfeNJU6qMdVA',
#  'vmhevPOT6au2sRnjdNbWBQ',
#  '4uAcvlBTSCJ4-IjkN4SxbQ',
#  '4nQl5B-oqSG8CW6rYZFCRw',
#  'KzeZtzeu8Qm4DJ73S031gw',
#  'OgMy6Q-l0tOEyRUZtROpIQ',
#  'rUzd-tR1uLQPmW2num25Rw',
#  'tG6NV7FexyV1u7R2yp99BQ',
#  'UoxNT2kxqnAfcFju2D0qVQ',
#  'KBwiYBIvUGI_eCxgqE_9wQ',
#  'dEFQoDcs2SFj17JlK4QS7w',
#  'GKdAe47v-Oa2ZWG4_8Zj9Q',
#  'ln4Lp601v5uD5ZLJu5Q6Fg',
#  'x4c1TSPIK924XlyGzEtaYQ',
#  'Rcs7gpbfhHpOXv3eY4IDJQ',
#  'tpf6VOnZuDRM-PGAmlqQ1Q',
#  'fW2vbzp6hTUdPLRif2RUkQ',
#  'fk173z-lDMdJx-_sFcqbdA',
#  'uHW8liLzdeFhNq57V-OdJg',
#  'T00s02ziow79JqZhnZ9hHw',
#  '_sKlDKzFqeOGSWuthU5LpQ',
#  'g6psOADT2rbrb2pWI7vQxA',
#  'QrPBnA83oSNj8RmQTMwEWg',
#  '7Ya-xx6S48baO9wY_-6Nig',
#  'cd9MmncJCQu5-h9FJxK9kA',
#  'N5qXxq8OdOUNf6biqSW5rw',
#  'km1ZoLMBB_eIevEfK6sCAA',
#  'NVvre3XEN9G6JNjACW-qbw',
#  '2rTsFlLLoVVsaEZ71IdFLw',
#  'VI-1gfoAOp3TmQLrwwzizw',
#  'MvXFZ84sPhMUZwNOljsaMA',
#  'mKDpi1qECb_rVIJ8yqbUiQ',
#  'heUQkE9FoeFrZnBMKrimZg',
#  '1YTEZbF731kpkjHS9BYFhA',
#  'tR-SQWwjtePur5uvDucihw',
#  'VmL-dn0-HY5fqr_cxIlMPQ',
#  'haE-TTYTbZkJPm7Dd9KivQ',
#  'sGyIlg7CwXS92KfgcAQ0uA',
#  '3xfpPJAxnT9n4t-Nv7nnrw',
#  '_-C37Eu1aFstjyH9Sj4HKA',
#  '42FMzM3yg3rrA37ycR06eQ',
#  'hdtnHbfsfyF4fP1_w3pWAw',
#  'W4rrgQ7Kni8zpIrJhvSsWA',
#  'kzUoZqJd7jX_YUPxp9EUzQ',
#  '-gGhj63r77Ufq9jv7T7B2w',
#  'lHFz5v8rVJy7iOLo_RfFBw',
#  'NPGNHXw_WnfyGBnjXPC-WA',
#  'Uss2uTNjvNrXY6qpymqnfQ',
#  '-u1T5pgYouWfyH7hbk3RQw',
#  'Okb0vL3kcPQnADkdqec9FQ',
#  'ZFja_smYSzIgjPLxWt7VPw',
#  'XnTRL_bmvwpHk0QsAnVO9A',
#  '0PKItmYLUdglsZQfeNN7Ag',
#  'b_VwbVQUawfQwkU7gBWQCA',
#  'DuTUsQnateTItzZNC5ttGA',
#  'RgMl5uyOS0v5O4y6sdKhnA',
#  'BbrfIrC55tQsRd5udEmxuA',
#  'QZWluBeJ6VpO3h3VS7_NsQ',
#  'TJWcpTGg5sxjP07p-YE7dQ',
#  '95uCEYbmFJaaCPLEVld6Xg',
#  'ui3qQUr5UzMjTf8MXSl4nw',
#  'v5tddyiqvnmr97dDSylcCg',
#  'JCMB0uW_GbpY4Xl4E6xrLA',
#  'CQ5KaqjOQGkX5D-96m3PyQ',
#  'jkWJTeiELiT2K3Z8yM2DOA',
#  '-7OmjZTokwVXVp5N2rEgQw',
#  'BtAzZGPzCjGI2L-oy5xFKA',
#  'XUPA1LbE6wnleh8wfwaK6w',
#  '20OAyOuV2_gjSiZCWppMTA',
#  '3Yb4ly4KuZd5HE-Dq_ESOQ',
#  'UUeI66a5pjNHWQSkDBt08g',
#  'uT6hou29wAkbX5tVOMcOhQ',
#  'JJa9AFMsOsRQOk-yBYEwbA',
#  '3qVDaazzMc1ZeSAfA-bh6A',
#  'pjJq5RvG6xG4o7_qX_P3hA',
#  '7mue6I-uXwLh7721ZUxieA',
#  'x2DjOIqDdZNOYSmMUx5FlA',
#  'WxoLYQUrDPE_dV4tAbpt-w',
#  'XaoDkHBdU7savLL-QnnbAQ',
#  'drdCjswQDjPsTYThJuT9zg',
#  '10pA8Y6Nm-Z6-fA4w1S3kQ',
#  'O-sW4Elt_7u2ylJFZkjXxg',
#  'CUjUnhusOgq3EZ363eSL1Q',
#  '4DZRZHvCwZaaJ3aCgLUpnQ',
#  'vcLirr5b8ZEM16kjAYER4Q',
#  '7JF625kykDgYWax2-8fpsQ',
#  'SJd2gT4iqs6E-PkPGa3sIQ',
#  'yu4K18E1G02Ue1l7HHyaSw',
#  'wYLRv2uR3VGvVrydWPv9ug',
#  '_M3SZ1EFj0NOF9gwTuDigA',
#  'PKnSxFiR55WUA0BKySNnxw',
#  'Q4ulqfklZvpz0HqiFGHJjQ',
#  '_RNGBB_esfh4goGRSxUtFw',
#  'kMhV3UHv9u8x5qC-tF143w',
#  'xKLjvn1kWgHLvUoYwF6k3g',
#  'nPsgGBflzwsDNXWZfaq8dg',
#  'k4usFxFTUbDzffs_I4EDLA',
#  'AzzBQM-7vy4Jxdtq00u1MQ',
#  '9JXG0nabYZKRAhuqmZ30BA',
#  'JPj05XLKn1l64sCWICe6TA',
#  '186de0m26t7DKwYMQux-0g',
#  'pwXR06vtq3OOk3S0Y0d1Tw',
#  '2PtG7ZfUZEIneJjL1J_asg',
#  'mvoMgDSlR2550ON8Zfd8ZQ',
#  '8z4a0zHkCUGBs9rzO_PUoQ',
#  '1F-J5VdETnENPRwekXlPQQ',
#  'Ejzedv3Z1iL3g5wgMWi3kw',
#  'i-3B_mYHgW8Meefy29cFwA',
#  '3LHV1JOn4XNtwdDDhT5z0Q',
#  'FfwZ35YFVumEJtxolnBAyQ',
#  'WgWznoU9GUcfWq_xV0swvA',
#  '3ulKuV3srv0ef6ZUZi0S2A',
#  '0tGlyFj255z-zpjUQF72KQ',
#  'J4a6L0aB4Bxf4ny9iWgATQ',
#  'Gb5B2woQVydAt9jLKkGnuQ',
#  '9eQWqmedaEVfdMlmE_Z5FQ',
#  '7aQYHRCYxTKAmawDGJ3YIw',
#  'K_v5t4VQHcZLl4cxXieDig',
#  'vPOd4qVpR2GHPgFWibSxTw',
#  'E0MIC8s4yVO1sqbo7p756w',
#  'J0ltGSBhUA74Bfa41N_l6A',
#  '1FaknROANzU18ZM9AkDh8Q',
#  '1ZkYQV9eUXN_Ly2G7b2geQ',
#  'UR1bX2YHQ30Uqd7lxKIpxA',
#  'g6U_cqItMcGV3bFoNXeHsA',
#  'VrCe1XQvfNFPfz4oUt6LDQ',
#  'nTY5XYMOYGGHaQL5bam7RA',
#  'RmWS1_hCPIe32ftSQ9YMkA',
#  'St6DcyvaxUCX7hmHKTJqTQ',
#  '5CzEbYs8Q9tz0HJoKfww2Q',
#  '32sftcXK2dl_Yby1hM5-PA',
#  'DzlmPGxCg3wRyGJiNoSFow',
#  'PhCuetu-kKemRw2gU6QmGg',
#  'sWDLtbXuEI3u2ujIXmLZBA',
#  'rFc5Zv2igHfb5Rck2-Do0w',
#  'i-wKgEc81T4-btaFoq9dSA',
#  'MDzALh67nH1-czACyB_CIg',
#  'Mxiki9ZQnVuME1s1K4sCWw',
#  'LibpXNT-8J1Fw6tXnlUUxQ',
#  '4eNrOBG7efnVJHBK1nxBdg',
#  'xChemndh4IiTimutQfyeQQ',
#  'xFgdPZMWoYuaTgBftX8LPA',
#  'v_Yph0ri3SjRcCa5dyjlww',
#  'LfFtWAUNwD3zT2zOOqYuKg',
#  'x_WgugK5_Y_mZ32Ox5ACqg',
#  'VTLwCn7_0dgLrpPBjjFPLg',
#  'azhV4OzVokTwewrMFw7ECA',
#  'l08XMp4SRfHpq4Wk8hf4vQ',
#  'wORtAyvsfiBJtfZDWMnXjA',
#  'Grpb9eR_EhLVTt2Z8WsRHg',
#  'Xvx9Oz06ZRKejDrz7OxiWA',
#  'jQhh-5J6M8tAAVS9IDRLHA',
#  'RmF8CTB2uIbNp8s1lUfIlg',
#  'F1k6qhB5lSASHblJCiHhCA',
#  'lHhVqcUimifamBXq734pPA',
#  'zygtalW0RfOQ0NlKwH9bPw',
#  'H2Q76vvXHa_3Yqg-kRTMLA',
#  'kjFAVD0Es0Cb1AnrDs3xdA',
#  '_rqxz18CPz6_-tLPzl66IQ',
#  '3YNnqmrM_iulliXm2gbEnw',
#  'KD3_1ENbfVU5lVBCx_J0LA',
#  'y-xmpkkrRNR4wa2Xc_IAwA',
#  'kYtuZxcze6wuh__1zIlpzQ',
#  'ljVyygHnwgx6_0YZKaeXRQ',
#  'wChYRl1Gf2Tngy7a8HU9ZQ',
#  'rjglt7PQ7Dgyh1-kO--_tg',
#  'oxGxc0KWukVi3LsHWSg40w',
#  'XcXp5331qdt_QmdkiMRW3w',
#  'T4jWNqIUWb2TkATSlJgHaw',
#  'UwVscJJUpLkbkEtBmsKGkQ',
#  '65WdLygWp9GTbZbGQaAalw',
#  'fkhv4IIePKb3GL0EOJR2Qw',
#  'cB2SaxiJpdMXUmcuE07NDQ',
#  'PHpOuiz1jCiZY_YOi71n1g',
#  'BUnzMs9X9tGdFz7BALPvXw',
#  'p7fi1MFj8HvD8iL042eB-A',
#  '8b4xgDOH4bextUIFJ-megw',
#  'r8Fsl16YpsfnuZZ7mAJ4hA',
#  '1Y7lcR7LWNsBsiU4T0oTvg',
#  'CeYftcwX7ezWRbtsNurqsg',
#  'T26qgrzS6OHML-nT6Vq0qA',
#  'glauk3WwAa1TR9cGyUOMlg',
#  '67BQB1tu0h_rPr2BQMorSw',
#  'XFtn15p80uNpYOVqjTpTWw',
#  'v1oSEKjF7EQGLQHR-zVPtw',
#  'kMXrOmQLf8d4wywTEyrt5A',
#  'yIyPXpGfwBbLUtrxOEQxBA',
#  'HAgdL87Ex7sQzktaA1PnkQ',
#  'D4lTHn02OmJr9YX-aLy1fA',
#  '8XY9FDqIGIizM8Fmo4y52A',
#  '1XeGGedZnWEtttcPjfiEYg',
#  'wM5hl4KQddc5cCq1xKoh4g',
#  'SPVEyqKVoVxqaCFkKCU0mA',
#  'DUGH1AYJpBW6Cx1oYRLy0A',
#  'bWlprZ0xNYfzfpJWr44iyQ',
#  'UBELuThqfUgeya-I2plz4A',
#  'Rf0jGmyES2hIpnn8J9yKHQ',
#  'FZ4GCNhht_yfSC7Esqwuvg',
#  'r_51_r7zBE-fEs5FlGMw3Q',
#  'cd9BcPyhxJZ1q6zaCCTgaA',
#  '4OX-XeetuonrqQgUCmgiJA',
#  'Y2zrdsSGF3zCs7AQNrViPA',
#  'BzG_-yjMDcrCebJOzeueuQ',
#  'S50Chk_5Iey9Qpo0dZaC4w',
#  '5rtvc8EA-bkWKptI1uVRzg',
#  'yZVaviIM3KVv1uXMNTsmyQ',
#  '8oF7HhqJJ_F_i1x0L-qCNA',
#  'tGn0b84Kk8BaJwo3_dAjdQ',
#  'rtZMa739rd-9kdPAikKygA',
#  'zgb1RcGD9-H5kIvbL5upLg',
#  'VVrL99JlQnN17AlBpqQLxQ',
#  'GNj9XqjoLBtaas966ir5fQ',
#  'KykNFjkhX2w1fLRallBc6w',
#  'K4LItE2nD3btBwlIY0elSw',
#  'zp5u1vVeNT_tPD1fPJjLog',
#  'NE6mkwjJ5BG1UXCdEutCOQ',
#  'f60m9mVNdeGR2IqE4FcD8Q',
#  '_uzY8TdsQjiFy_8Tq1RbpQ',
#  'WUDTX9faUAgg-VaRzR_LAw',
#  'OOU3LoxoBOW-4veBHbLVHQ',
#  '2bsXe7YsO10zqmyjk1jmYw',
#  '8YnFKNYTiBa1L-6OVgp5rA',
#  'QgbfpsnVULBg9o8Yqhyc_A',
#  'x25t8G_7Lo9Wd7Grdn_HEw',
#  'ceVnwNrium3dbyFMNE_PcA',
#  'Ss2RTJiQ_vODLTUs6hyERQ',
#  'A0I9yKu_hogweqQjXEtsMg',
#  'NpXLOuyMRsUdzc59RfQByw',
#  '00bS6O7_Ux8Pl51MFBB7mQ',
#  'XXUkQHHsp-ZKcaSEYTN_Pg',
#  'KQmm6Y1mGAm7GjQ1Ubd0Jg',
#  'ZNlIInu9fSVoEGev-mxZ2A',
#  't1lK5-unGnN_ph841N80wQ',
#  '8HhmzxsiLAFSVFwCpW_0sA',
#  'FHeb4dYz-LEGtyy--HKexg',
#  'd39o5ud7fwRbk5voplSi4A',
#  's0mrjPd7eIkM1SYVi2g2Bg',
#  'OlKzkrBgIBCqdzTDOhkKbA',
#  'aQDijRZoKHJyEHaQzHEd9w',
#  'UYohTHGTm-5GfyoaS1_D3Q',
#  '80jo9oy5couYw25WKeVnyg',
#  'wn-nUqLskTaJY8R8IfVkYw',
#  'zYYzDrARuMQoSjf4LhGwSg',
#  'dSQYZC7Y1SXGXlf4e90k8g',
#  'CKqMGXLwPkkWip9XSXGq8g',
#  't4P99UqsmNJJlrPOAwKbcg',
#  '235RuPbkitqZka9HJJ3evA',
#  'qxBnUlbpJUGUxcx3VPDGZg',
#  'pYp5IoSC9HuaZTAPsqyOFA',
#  'p_0uP2GZBwRnuJsP3kUpcQ',
#  'fVKRJHRemkpJTwUOm6l2xQ',
#  'gb9kmgyAetl47pLmaWbkxQ',
#  'a2lZaO-3N8rO096h7FOynA',
#  'dF6Q2mEP6MX2apmaHKE6wA',
#  '1DBm773TDxE2sF-H0GCnRg',
#  'qPmmgMOXUJb09diIs5Z82Q',
#  'gkjPqe952Wl1xIdywZVIQw',
#  'r1HvIAjWI9bCrElyrxBuSQ',
#  'OO9SgjbLi3nyt63hRir0LQ',
#  'eKUzNl4MvxbxLU6LCOY33A',
#  'WM-m1vQCMSfu6iDysNaoAQ',
#  'D1P7yspJBjOcyNiDBchnHw',
#  '6IhiqwZ0BS7Qfom3qrhWiQ',
#  'XOAkJJ759BF1HkapiyGg-Q',
#  'JlFLkNrg8k7qoOdhb-AeTA',
#  '-iA0I_ZcwEZdz7W8PEmJvA',
#  'DypJfifuqqZW60D9Gt9Gvw',
#  'GQHhowxLKEt509fWGSxtSQ',
#  'WNawSG7NIJWaN1QUsYOdRg',
#  'RJLCRtW_c5fZfGcLAEo2PQ',
#  'JiH5rnOlw7DzysKd41WdSg',
#  'fdY7Cus2Lo2nQrUv_M7zCw',
#  'Ag-dQZ3rGqt8W6CnlNJNqw',
#  'n0ZDEXWuGkqXSmkH7D60Dg',
#  'khP-qZ96sasIj8yhGsj-5Q',
#  'cyaM9MzkPFnyaYJTSqwN3Q',
#  'qb6TMcDuK2Nu4Y_vm85ldw',
#  '--3kLXdVcWt_HuhyyWwHOw',
#  'bX9sN1y6Wq2cfCGc_4Zdug',
#  'yL2nF8k8y7Dn-M6JA4eyvw',
#  'lU1cFtgqdS-Yz317VEUpmA',
#  '6nVFYZ99dMy4qnDcler_jg',
#  'D1kxEcTbVdwd3G5C1LYAjw',
#  'qYb1ITEgz1tc03gdIJSrfQ',
#  'OEd5RHZ3lM0PCkqYXZJ6dw',
#  'uD88y_TZSCSi3xkuWu_8wg',
#  '-rphqFuHAKO2poZF1RHn1A',
#  'AptO1Y8NpRla8nbRK8R67w',
#  'GtYs6kuONl2SPagmhuRhKg',
#  'KhopHxSwn6rQYQRdb0nTtw',
#  'a-s5p0UBfBp1kg4O5hLyrg',
#  'UESe9VrLWUCHcc75315shA',
#  'vvcnhViCOxOTCTWIkHlCuw',
#  'dwpSfZWXYnuRg6v7FmCrPg',
#  'R489QRPFe1rLSBeI5c4scg',
#  'D3GQOVR9MKQBt_POvROgtQ',
#  '9UuC7wdMU0N1S6ViAtpuDw',
#  'K75UTsSK5AwrGtCx5yoavw',
#  'BocSTAYg8V0Jn0IBpG26pA',
#  '5rVTrASbIR6tFo82xz9OKA',
#  '1vJWuQ9Rm4lQq0WL61wdsQ',
#  'N_fjnSwoi9QSN1_i1strtA',
#  'xugfgNHlFCuo7C_8WhV7mQ',
#  'kCfk0g1_SVR_2q_xVe0waw',
#  'bdGcqiJierloZAskBy8OEQ',
#  'p121hnQFWV1YPY82Z7NADA',
#  'd6fnuCeDj8FCrV6M-YzSsA',
#  'vGCYtwPKPdqvIrHG1o1iqg',
#  'jOobCeoSERjqPA9jtFnhEg',
#  'Q4jZXWeH-FFUgj-i_tYkHg',
#  'AL_CuRqvkCH1h_czuLPTpA',
#  'qO6gZWoVMg23uf2xziNLow',
#  'SyQ0tjkHQe0UXyDRmo4sIQ',
#  'rGxhn6FYSQztzXMouPuEjw',
#  '1355fpXlKnj0O49dDE8u1Q',
#  'T6L0l4OyFaOC3iLfFDpyYg',
#  'PMqPQh4JLxjisYlhqifzeg',
#  '6YM4sTvinGAmPldrJv3G4A',
#  'PFrqcAEFJ1QNfUjlxYz_5A',
#  'mut-NtsrMsR_B9fXBeUy3w',
#  'uis6vcPyUFHb0FTGy1zfRQ',
#  'P296OXS_TPa_c_pP2GsSdg',
#  'GLzJ-DWZQ6tn1gjtI_IhzQ',
#  'kW8wW3yJBUFn8RVK9dQFqg',
#  'Wa2I7VS4Saslh0Xa--sGdQ',
#  'dcmuXaoHGbPRgnASR9EHVQ',
#  ...]

# %%
def yelp_call_reviews(ID):
        url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(ID)
    # your code to make the yelp call
        response = requests.get(url, headers=headers)
        data = response.json()
        return data

# %%
def parse_reviews(businessID, review_results):
    tuple_lists = []
    
    if 'error' in review_results:
        if review_results['error']['code'] == 'BUSINESS_UNAVAILABLE':
            return None
            
    else:
        for review in review_results['reviews']:
            for item in ['text', 'rating', 'time_created']:
                if item not in review:
                    review[item] = np.nan
                review_tuple =( businessID, 
                                review['text'],
                                review['rating'],
                                review['time_created'],
                                review['id']
                              )
                tuple_lists.append(review_tuple)
    
    return tuple_lists

# %%
def insert_reviews(conn, cur, parse_reviews):
        add_reviews = ("""
        INSERT INTO reviews (businessID, text, rating, time_created, reviewID)
        VALUES (?, ?, ?, ?, ?) """)
        cur.executemany(add_reviews, parse_reviews)
        conn.commit()

# %%
# create a variable  to keep track of which result you are in. 
#num = NYCdata['total']
#set up a while loop to go through and grab the result 

for biz in biz_ID_list:
    #set the offset parameter to be where you currently are in the results 
    #make your API call with the new offset number
    review_results = yelp_call_reviews(biz)
    if review_results == None:
        pass
    parsed_reviews = parse_reviews(biz, review_results)
    insert_reviews(conn, cur, parsed_reviews)
    #increment the counter by 50 to move on to the next results

# %%
cur.execute("""
SELECT * FROM businesses
""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#         id              businessID  rating price                     name  \
# 0        1  kmj7FnZsKPPH3psbR9tX7Q     4.5  None               Sonic Yoga
# 1        2  GgvXfu8U80tcrxythjpB4w     5.0  None              AtthenaYoga
# 2        3  TlDcvf1cEK2im6e4AFYe3A     4.5  None            Humming Puppy
# 3        4  npgq_up0_puDV5jieUza-A     4.5  None                 Yo Yoga!
# 4        5  Oi85AYz9-Bx-9SBjNf__vg     4.5  None     Yoga Spa Lounge 1881
# ...    ...                     ...     ...   ...                      ...
# 1174  1175  XCOdN4pGetfR8Ema258z3w     2.5  None               DW FITNESS
# 1175  1176  Q-nSJQDBRyn9Ahqc4oRlRg     3.5  None  Fitness First Broadgate
# 1176  1177  MEUESxTbldQnKrU7_9g4Yw     4.0  None                    Mettá
# 1177  1178  zI399ArMHUW9uDNkTciDPA     3.5  None            Virgin Active
# 1178  1179  s0W-AbYi0mGw6egZ2rk_Ow     3.0   £££       Equinox Kensington
#
#      review_count        city country  zip_code
# 0             146    New York      US     10019
# 1              42    New York      US     10036
# 2              90    New York      US     10011
# 3              55    New York      US     10022
# 4              92    New York      US     10022
# ...           ...         ...     ...       ...
# 1174            7      London      GB  WC2B 4DD
# 1175            3      London      GB  EC2M 7PY
# 1176            1      London      GB   NW5 1NA
# 1177            9      London      GB   SW4 0HG
# 1178           27  Kensington      GB        W8
#
# [1179 rows x 9 columns]

# %%
cur.execute("""
SELECT * FROM reviews
""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#                   businessID  \
# 0     kmj7FnZsKPPH3psbR9tX7Q
# 1     kmj7FnZsKPPH3psbR9tX7Q
# 2     kmj7FnZsKPPH3psbR9tX7Q
# 3     kmj7FnZsKPPH3psbR9tX7Q
# 4     kmj7FnZsKPPH3psbR9tX7Q
# ...                      ...
# 9322  s0W-AbYi0mGw6egZ2rk_Ow
# 9323  s0W-AbYi0mGw6egZ2rk_Ow
# 9324  s0W-AbYi0mGw6egZ2rk_Ow
# 9325  s0W-AbYi0mGw6egZ2rk_Ow
# 9326  s0W-AbYi0mGw6egZ2rk_Ow
#
#                                                    text  rating  \
# 0     Beginner Flow with Taquice, Sunday afternoon -...       5
# 1     Beginner Flow with Taquice, Sunday afternoon -...       5
# 2     Beginner Flow with Taquice, Sunday afternoon -...       5
# 3     I came across Sonic Yoga on ClassPass.  I have...       4
# 4     I came across Sonic Yoga on ClassPass.  I have...       4
# ...                                                 ...     ...
# 9322  This location puts San Francisco Equinox Sport...       4
# 9323  This location puts San Francisco Equinox Sport...       4
# 9324  My father's old business partner's daughter in...       3
# 9325  My father's old business partner's daughter in...       3
# 9326  My father's old business partner's daughter in...       3
#
#              time_created                reviewID
# 0     2019-12-29 14:26:23  QJS08cT1I7c0Ev9u6femLw
# 1     2019-12-29 14:26:23  QJS08cT1I7c0Ev9u6femLw
# 2     2019-12-29 14:26:23  QJS08cT1I7c0Ev9u6femLw
# 3     2020-02-28 06:21:41  1lBvdI7kfUrWN59njKQsZw
# 4     2020-02-28 06:21:41  1lBvdI7kfUrWN59njKQsZw
# ...                   ...                     ...
# 9322  2016-08-01 12:34:31  1s1M_DJNdqHvEg2xLHChYQ
# 9323  2016-08-01 12:34:31  1s1M_DJNdqHvEg2xLHChYQ
# 9324  2018-08-08 08:30:27  sJdmd9ZYZf-BJ4SNKI-iVw
# 9325  2018-08-08 08:30:27  sJdmd9ZYZf-BJ4SNKI-iVw
# 9326  2018-08-08 08:30:27  sJdmd9ZYZf-BJ4SNKI-iVw
#
# [9327 rows x 5 columns]

# %%
# Which are the 5 most reviewed businesses?
cur.execute("""
SELECT name 
FROM businesses
ORDER By review_count DESC
LIMIT 5
""").fetchall()
# Out:
# [('Vanderbilt Branch YMCA',),
#  ('Work it Out',),
#  ('Foxy Fitness & Pole Training Studios',),
#  ('Church Street Boxing Gym',),
#  ('Bedford-Stuyvesant Branch YMCA',)]

# %%
#What is the highest rating recieved in your data set and how many businesses have that rating?
cur.execute("""
SELECT rating, COUNT(rating)
FROM businesses
WHERE rating = (SELECT MAX(rating) FROM businesses)
""").fetchall()
# Out:
# [(5, 528)]

# %%
# What percentage of businesses have a rating greater than or 4.5?
cur.execute("""
SELECT
COUNT(*)*100/ (SELECT COUNT(*) FROM businesses)
FROM businesses 
WHERE rating < 4.5
""").fetchall()
# Out:
# [(32,)]

# %%
# What percentage of businesses have a rating less than 3?
cur.execute("""
SELECT
COUNT(*)*100/ (SELECT COUNT(*) FROM businesses)
FROM businesses 
WHERE rating < 3
""").fetchall()
# Out:
# [(3,)]

# %%
# What is the average rating of businesses that have a price label of one dollar sign? 
# Two dollar signs? Three dollar signs?
cur.execute("""
SELECT AVG(rating) AS AvgRating, price
FROM businesses
GROUP BY price
HAVING price = '$' OR price = '$$' OR price = '$$$'
""").fetchall()
# Out:
# [(4.25, '$'), (4.1923076923076925, '$$'), (3.4516129032258065, '$$$')]

# %%
#Return the text of the reviews for the most reviewed business.
cur.execute("""
SELECT text
FROM reviews
WHERE businessID in (SELECT businessID
                     FROM businesses
                     ORDER BY review_count
                     LIMIT 1
                     );
""").fetchall()
# Out:
# [('I came away very impressed after some session stress management and yoga sessions with Eiji. His calm demeanor and clear instructions made it a very easy to...',),
#  ('I came away very impressed after some session stress management and yoga sessions with Eiji. His calm demeanor and clear instructions made it a very easy to...',),
#  ('I came away very impressed after some session stress management and yoga sessions with Eiji. His calm demeanor and clear instructions made it a very easy to...',)]

# %%
# Return the name of the business with the most recent review.
cur.execute("""
SELECT name
FROM businesses
WHERE businessID in (SELECT businessID
                     FROM reviews
                     ORDER BY time_created DESC
                     LIMIT 1);

""").fetchall()
# Out:
# [('Five Pillars Yoga',)]

# %%
# Find the highest rated business and return text of the most recent review. 
# If multiple business have the same rating, select the business with the most reviews.
cur.execute("""
SELECT text
FROM reviews AS r
JOIN businesses AS b
ON r.businessID = b.businessID
ORDER BY review_count DESC, b.rating DESC
LIMIT 1
""").fetchall()
# Out:
# [('I was member here for 15+ years. The karate program was pretty good, most of the staff is great (with the exception to a few people), the gym is nice and...',)]

# %%
# Find the lowest rated business and return text of the most recent review. 
# If multiple business have the same rating, select the business with the least reviews.
cur.execute("""
SELECT text
FROM reviews AS r
JOIN businesses AS b
ON r.businessID = b.businessID
ORDER BY  b.rating ASC, review_count ASC
LIMIT 1
""").fetchall()
# Out:
# [('Participated in a photo shoot for this studio way back in 2018, and was promised TFP not long after. 2 years and multiple failed contact attempts later,...',)]

# %%
cur.execute("""
SELECT * FROM businesses
""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#         id              businessID  rating price                     name  \
# 0        1  kmj7FnZsKPPH3psbR9tX7Q     4.5  None               Sonic Yoga
# 1        2  GgvXfu8U80tcrxythjpB4w     5.0  None              AtthenaYoga
# 2        3  TlDcvf1cEK2im6e4AFYe3A     4.5  None            Humming Puppy
# 3        4  npgq_up0_puDV5jieUza-A     4.5  None                 Yo Yoga!
# 4        5  Oi85AYz9-Bx-9SBjNf__vg     4.5  None     Yoga Spa Lounge 1881
# ...    ...                     ...     ...   ...                      ...
# 1174  1175  XCOdN4pGetfR8Ema258z3w     2.5  None               DW FITNESS
# 1175  1176  Q-nSJQDBRyn9Ahqc4oRlRg     3.5  None  Fitness First Broadgate
# 1176  1177  MEUESxTbldQnKrU7_9g4Yw     4.0  None                    Mettá
# 1177  1178  zI399ArMHUW9uDNkTciDPA     3.5  None            Virgin Active
# 1178  1179  s0W-AbYi0mGw6egZ2rk_Ow     3.0   £££       Equinox Kensington
#
#      review_count        city country  zip_code
# 0             146    New York      US     10019
# 1              42    New York      US     10036
# 2              90    New York      US     10011
# 3              55    New York      US     10022
# 4              92    New York      US     10022
# ...           ...         ...     ...       ...
# 1174            7      London      GB  WC2B 4DD
# 1175            3      London      GB  EC2M 7PY
# 1176            1      London      GB   NW5 1NA
# 1177            9      London      GB   SW4 0HG
# 1178           27  Kensington      GB        W8
#
# [1179 rows x 9 columns]

# %%
cur.execute("""
SELECT * FROM reviews
""")
df1 = pd.DataFrame(cur.fetchall())
df1.columns = [x[0] for x in cur.description]
df1
# Out:
#                   businessID  \
# 0     kmj7FnZsKPPH3psbR9tX7Q
# 1     kmj7FnZsKPPH3psbR9tX7Q
# 2     kmj7FnZsKPPH3psbR9tX7Q
# 3     kmj7FnZsKPPH3psbR9tX7Q
# 4     kmj7FnZsKPPH3psbR9tX7Q
# ...                      ...
# 9322  s0W-AbYi0mGw6egZ2rk_Ow
# 9323  s0W-AbYi0mGw6egZ2rk_Ow
# 9324  s0W-AbYi0mGw6egZ2rk_Ow
# 9325  s0W-AbYi0mGw6egZ2rk_Ow
# 9326  s0W-AbYi0mGw6egZ2rk_Ow
#
#                                                    text  rating  \
# 0     Beginner Flow with Taquice, Sunday afternoon -...       5
# 1     Beginner Flow with Taquice, Sunday afternoon -...       5
# 2     Beginner Flow with Taquice, Sunday afternoon -...       5
# 3     I came across Sonic Yoga on ClassPass.  I have...       4
# 4     I came across Sonic Yoga on ClassPass.  I have...       4
# ...                                                 ...     ...
# 9322  This location puts San Francisco Equinox Sport...       4
# 9323  This location puts San Francisco Equinox Sport...       4
# 9324  My father's old business partner's daughter in...       3
# 9325  My father's old business partner's daughter in...       3
# 9326  My father's old business partner's daughter in...       3
#
#              time_created                reviewID
# 0     2019-12-29 14:26:23  QJS08cT1I7c0Ev9u6femLw
# 1     2019-12-29 14:26:23  QJS08cT1I7c0Ev9u6femLw
# 2     2019-12-29 14:26:23  QJS08cT1I7c0Ev9u6femLw
# 3     2020-02-28 06:21:41  1lBvdI7kfUrWN59njKQsZw
# 4     2020-02-28 06:21:41  1lBvdI7kfUrWN59njKQsZw
# ...                   ...                     ...
# 9322  2016-08-01 12:34:31  1s1M_DJNdqHvEg2xLHChYQ
# 9323  2016-08-01 12:34:31  1s1M_DJNdqHvEg2xLHChYQ
# 9324  2018-08-08 08:30:27  sJdmd9ZYZf-BJ4SNKI-iVw
# 9325  2018-08-08 08:30:27  sJdmd9ZYZf-BJ4SNKI-iVw
# 9326  2018-08-08 08:30:27  sJdmd9ZYZf-BJ4SNKI-iVw
#
# [9327 rows x 5 columns]

# %%
Avg_Country = cur.execute("""
SELECT rating, city
FROM businesses
GROUP BY country 
""").fetchall()

# %%
Avg_Country = df.groupby('country')['rating'].mean()

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.bar(Avg_Country.index, Avg_Country.values, color = ('Red', 'blue'), width = 0.4)

ax.set_xlabel("City")
ax.set_ylabel("Average rating")
ax.set_title("Average Rating for Yoga Studios for each Location ")
plt.show()

# %%
cur.execute("""
SELECT city, rating, review_count
FROM businesses
GROUP BY country
""")
avgR = pd.DataFrame(cur.fetchall())
avgR.columns = [x[0] for x in cur.description]
avgR
# Out:
#        city  rating review_count
# 0    London     5.0            1
# 1  New York     4.5          146

# %%
avgR.rating
# Out:
# 0    5.0
# 1    4.5
# Name: rating, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (10,8))

# Add data: "height", "weight" as x-y, index as color
ax.boxplot([avgR.rating, avgR.review_count])

# Set the x-axis label to "CO2 (ppm)"
ax.set_xticklabels(['London', "New York"])

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Review Counts")

ax.set_title('Average number of reviews For Lond and New York')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-a07cad4e1a64> in <module>
#       2
#       3 # Add data: "height", "weight" as x-y, index as color
# ----> 4 ax.boxplot([avgR.rating, avgR.review_count])
#       5
#       6 # Set the x-axis label to "CO2 (ppm)"
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3681             bootstrap = rcParams['boxplot.bootstrap']
#    3682
# -> 3683         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3684                                        labels=labels, autorange=autorange)
#    3685         if notch is None:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1175
#    1176         # arithmetic mean
# -> 1177         stats['mean'] = np.mean(x)
#    1178
#    1179         # medians and quartiles
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3332             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3333
# -> 3334     return _methods._mean(a, axis=axis, dtype=dtype,
#    3335                           out=out, **kwargs)
#    3336
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     161             ret = ret.dtype.type(ret / rcount)
#     162     else:
# --> 163         ret = ret / rcount
#     164
#     165     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
cur.execute("""
SELECT price, city, review_count
FROM businesses 
WHERE price = '$$$$' OR price = '$$$' OR price = '$$' OR price = '$'
""")
priceNYCdb = pd.DataFrame(cur.fetchall())
priceNYCdb.columns = [x[0] for x in cur.description]
priceNYCdb
# Out:
#    price           city review_count
# 0     $$       New York           10
# 1     $$       New York            1
# 2     $$    Jersey City           40
# 3    $$$       New York          269
# 4    $$$     Guttenberg           38
# 5     $$       New York            9
# 6    $$$       New York          105
# 7    $$$       New York           12
# 8     $$       New York            4
# 9      $       New York          138
# 10    $$       New York           68
# 11     $       Bushwick          127
# 12    $$      Manhattan            1
# 13   $$$       New York           63
# 14   $$$       New York           18
# 15    $$        Astoria           36
# 16     $       New York           53
# 17   $$$       New York          111
# 18   $$$       New York          151
# 19   $$$       New York            4
# 20   $$$       New York           33
# 21   $$$       New York           36
# 22   $$$  New York City           16
# 23    $$       Brooklyn           59
# 24   $$$       New York           84
# 25   $$$       New York          178
# 26   $$$       New York          354
# 27     $       New York          113
# 28   $$$       New York           30
# 29   $$$       New York           93
# 30   $$$      Manhattan            6
# 31   $$$       New York           43
# 32   $$$       New York           88
# 33   $$$       New York          134
# 34   $$$       New York           43
# 35   $$$       New York          125
# 36   $$$       New York          119
# 37    $$       New York           29
# 38    $$       New York            6
# 39   $$$       New York          104
# 40   $$$       New York           63
# 41   $$$       New York           85
# 42    $$       New York           13
# 43   $$$       New York           66
# 44    $$    Jersey City           14
# 45   $$$       New York          148
# 46   $$$       New York          105
# 47   $$$       New York           76
# 48  $$$$       New York          128

# %%
newcolumn = []

for x in priceNYCdb['price']:
    if x == '$':
        newcolumn.append(int(x.replace('$', str(1))))
    if x == '$$':
        newcolumn.append(int(x.replace('$$', str(2))))
    if x == '$$$':
        newcolumn.append(int(x.replace('$$$', str(3))))
    if x == '$$$$':
        newcolumn.append(int(x.replace('$$$$', str(4))))

# %%
priceNYCdb['newPrice'] = newcolumn

# %%
cur.execute("""
SELECT price, city, review_count
FROM businesses 
WHERE price = '££££' OR price = '£££' OR price = '££' OR price = '£'

""")
priceUKdb = pd.DataFrame(cur.fetchall())
priceUKdb.columns = [x[0] for x in cur.description]
priceUKdb
# Out:
#    price        city review_count
# 0     ££      London            8
# 1    £££      London            7
# 2    £££        Soho           15
# 3     ££      London            5
# 4    £££      London            2
# 5     ££      London            6
# 6   ££££      London            7
# 7    £££      London            4
# 8     ££      London            2
# 9   ££££      London            2
# 10   £££  Kensington           27

# %%
newcolumnUK = []

for x in priceUKdb['price']:
    if x == '£':
        newcolumnUK.append(int(x.replace('£', str(1))))
    if x == '££':
        newcolumnUK.append(int(x.replace('££', str(2))))
    if x == '£££':
        newcolumnUK.append(int(x.replace('£££', str(3))))
    if x == '££££':
        newcolumnUK.append(int(x.replace('££££', str(4))))

# %%
priceUKdb['newPrice'] = newcolumnUK

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(priceNYCdb['newPrice'], label = 'NYC',  color = 'blue')

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(priceUKdb['newPrice'], label= 'London', color = 'red')

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel('Price range from least to most expensive')

# Set the y-axis label to "# of observations"
ax.set_ylabel('Number of Observations')

ax.set_title('Pricing of Yoga studios in the UK and NYC')

ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Add data: "height", "weight" as x-y, index as color
ax.scatter(priceNYCdb["newPrice"], priceNYCdb["review_count"])

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("Price range 1-4")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Number of Review Counts")

ax.set_title('Correlation between Price and Review Counts')


plt.show()
